# %% [markdown]
# # RotateSH

# %%
import numpy as np
import torch as th
import pytorch_lightning as pl
pl.seed_everything(47)

sj_id = list(range(1, 21))
vs_pair = ['difareli++-vs-ic_light', 
           'difareli++-vs-hou21_shadowm', 
           'difareli++-vs-hou22_geom', 
           'difareli++-vs-diffusionrig',
           'difareli++-vs-relipa'
        ]

# Many-to-Many for sj_id and vs_pair
sj_dict = {}
for sj in sj_id:
    sj_dict[f'pair{sj}'] = [vs for vs in vs_pair]
print("[#] Length of sj_dict: ", len(sj_dict))
print("[#] Each sj has vs_pair: ", len(sj_dict['pair1']))
print("Example: ", list(sj_dict.items())[0])
print("Example: ", list(sj_dict.items())[1])

# Create Global Chunks that each chunk has n sj and keep iterate until that sj has empty vs, then remove that sj
n_sj_total = len(sj_dict)
n_sj_per_chunk = 10
out = []
total_elem = sum([len(v) for v in sj_dict.values()])
print("[#] Total elements: ", total_elem)

all_chunks = []
n_round = total_elem // n_sj_per_chunk
for r in range(n_round):
    # Each round we create a chunk
    # Since we have 20 sj, we iterate 2 times to fill 10 sj
    keys = list(sj_dict.keys())
    np.random.shuffle(keys)
    keys_iters = [keys[:n_sj_per_chunk], keys[n_sj_per_chunk:]]

    for i in range(n_sj_total // n_sj_per_chunk):
        chunk = []
        print(f"[#] Round {r}: keys_iters[{i}]: ", keys_iters[i])
        for k in keys_iters[i]:
            print(f"\t[#] Round {r}: key {k}")
            if len(sj_dict[k]) > 0 and len(chunk) < n_sj_per_chunk:
                v = np.random.choice(sj_dict[k], size=1, replace=False)[0]
                chunk.append( (k, v) )
                sj_dict[k].remove(v)
        all_chunks.append(chunk)
print("[#] Total chunks: ", len(all_chunks))
print("Total elements in all chunks: ", sum([len(c) for c in all_chunks]))
print("Example chunk: ", all_chunks[0])
print("Example chunk: ", all_chunks[1])
print("Final sj_dict: ", sj_dict)
# Out:
# Seed set to 47
# [#] Length of sj_dict:  20
# [#] Each sj has vs_pair:  5
# Example:  ('pair1', ['difareli++-vs-ic_light', 'difareli++-vs-hou21_shadowm', 'difareli++-vs-hou22_geom', 'difareli++-vs-diffusionrig', 'difareli++-vs-relipa'])
# Example:  ('pair2', ['difareli++-vs-ic_light', 'difareli++-vs-hou21_shadowm', 'difareli++-vs-hou22_geom', 'difareli++-vs-diffusionrig', 'difareli++-vs-relipa'])
# [#] Total elements:  100
# [#] Round 0: keys_iters[0]:  ['pair11', 'pair15', 'pair19', 'pair5', 'pair16', 'pair3', 'pair2', 'pair6', 'pair10', 'pair13']
# 	[#] Round 0: key pair11
# 	[#] Round 0: key pair15
# 	[#] Round 0: key pair19
# 	[#] Round 0: key pair5
# 	[#] Round 0: key pair16
# 	[#] Round 0: key pair3
# 	[#] Round 0: key pair2
# 	[#] Round 0: key pair6
# 	[#] Round 0: key pair10
# 	[#] Round 0: key pair13
# [#] Round 0: keys_iters[1]:  ['pair14', 'pair12', 'pair18', 'pair1', 'pair4', 'pair17', 'pair9', 'pair20', 'pair7', 'pair8']
# 	[#] Round 0: key pair14
# 	[#] Round 0: key pair12
# 	[#] Round 0: key pair18
# 	[#] Round 0: key pair1
# 	[#] Round 0: key pair4
# 	[#] Round 0: key pair17
# 	[#] Round 0: key pair9
# 	[#] Round 0: key pair20
# 	[#] Round 0: key pair7
# 	[#] Round 0: key pair8
# [#] Round 1: keys_iters[0]:  ['pair18', 'pair20', 'pair3', 'pair4', 'pair11', 'pair6', 'pair17', 'pair15', 'pair10', 'pair13']
# 	[#] Round 1: key pair18
# 	[#] Round 1: key pair20
# 	[#] Round 1: key pair3
# 	[#] Round 1: key pair4
# 	[#] Round 1: key pair11
# 	[#] Round 1: key pair6
# 	[#] Round 1: key pair17
# 	[#] Round 1: key pair15
# 	[#] Round 1: key pair10
# 	[#] Round 1: key pair13
# [#] Round 1: keys_iters[1]:  ['pair16', 'pair2', 'pair9', 'pair19', 'pair12', 'pair8', 'pair7', 'pair14', 'pair5', 'pair1']
# 	[#] Round 1: key pair16
# 	[#] Round 1: key pair2
# 	[#] Round 1: key pair9
# 	[#] Round 1: key pair19
# 	[#] Round 1: key pair12
# 	[#] Round 1: key pair8
# 	[#] Round 1: key pair7
# 	[#] Round 1: key pair14
# 	[#] Round 1: key pair5
# 	[#] Round 1: key pair1
# [#] Round 2: keys_iters[0]:  ['pair18', 'pair20', 'pair15', 'pair16', 'pair12', 'pair4', 'pair3', 'pair5', 'pair10', 'pair14']
# 	[#] Round 2: key pair18
# 	[#] Round 2: key pair20
# 	[#] Round 2: key pair15
# 	[#] Round 2: key pair16
# 	[#] Round 2: key pair12
# 	[#] Round 2: key pair4
# 	[#] Round 2: key pair3
# 	[#] Round 2: key pair5
# 	[#] Round 2: key pair10
# 	[#] Round 2: key pair14
# [#] Round 2: keys_iters[1]:  ['pair6', 'pair2', 'pair13', 'pair19', 'pair17', 'pair9', 'pair8', 'pair1', 'pair7', 'pair11']
# 	[#] Round 2: key pair6
# 	[#] Round 2: key pair2
# 	[#] Round 2: key pair13
# 	[#] Round 2: key pair19
# 	[#] Round 2: key pair17
# 	[#] Round 2: key pair9
# 	[#] Round 2: key pair8
# 	[#] Round 2: key pair1
# 	[#] Round 2: key pair7
# 	[#] Round 2: key pair11
# [#] Round 3: keys_iters[0]:  ['pair4', 'pair1', 'pair6', 'pair8', 'pair13', 'pair9', 'pair15', 'pair14', 'pair19', 'pair17']
# 	[#] Round 3: key pair4
# 	[#] Round 3: key pair1
# 	[#] Round 3: key pair6
# 	[#] Round 3: key pair8
# 	[#] Round 3: key pair13
# 	[#] Round 3: key pair9
# 	[#] Round 3: key pair15
# 	[#] Round 3: key pair14
# 	[#] Round 3: key pair19
# 	[#] Round 3: key pair17
# [#] Round 3: keys_iters[1]:  ['pair10', 'pair18', 'pair20', 'pair12', 'pair11', 'pair3', 'pair7', 'pair5', 'pair2', 'pair16']
# 	[#] Round 3: key pair10
# 	[#] Round 3: key pair18
# 	[#] Round 3: key pair20
# 	[#] Round 3: key pair12
# 	[#] Round 3: key pair11
# 	[#] Round 3: key pair3
# 	[#] Round 3: key pair7
# 	[#] Round 3: key pair5
# 	[#] Round 3: key pair2
# 	[#] Round 3: key pair16
# [#] Round 4: keys_iters[0]:  ['pair1', 'pair6', 'pair5', 'pair4', 'pair19', 'pair3', 'pair12', 'pair9', 'pair14', 'pair8']
# 	[#] Round 4: key pair1
# 	[#] Round 4: key pair6
# 	[#] Round 4: key pair5
# 	[#] Round 4: key pair4
# 	[#] Round 4: key pair19
# 	[#] Round 4: key pair3
# 	[#] Round 4: key pair12
# 	[#] Round 4: key pair9
# 	[#] Round 4: key pair14
# 	[#] Round 4: key pair8
# [#] Round 4: keys_iters[1]:  ['pair20', 'pair2', 'pair17', 'pair16', 'pair10', 'pair11', 'pair18', 'pair13', 'pair15', 'pair7']
# 	[#] Round 4: key pair20
# 	[#] Round 4: key pair2
# 	[#] Round 4: key pair17
# 	[#] Round 4: key pair16
# 	[#] Round 4: key pair10
# 	[#] Round 4: key pair11
# 	[#] Round 4: key pair18
# 	[#] Round 4: key pair13
# 	[#] Round 4: key pair15
# 	[#] Round 4: key pair7
# [#] Round 5: keys_iters[0]:  ['pair11', 'pair12', 'pair7', 'pair20', 'pair8', 'pair13', 'pair18', 'pair10', 'pair14', 'pair19']
# 	[#] Round 5: key pair11
# 	[#] Round 5: key pair12
# 	[#] Round 5: key pair7
# 	[#] Round 5: key pair20
# 	[#] Round 5: key pair8
# 	[#] Round 5: key pair13
# 	[#] Round 5: key pair18
# 	[#] Round 5: key pair10
# 	[#] Round 5: key pair14
# 	[#] Round 5: key pair19
# [#] Round 5: keys_iters[1]:  ['pair3', 'pair6', 'pair1', 'pair9', 'pair17', 'pair15', 'pair5', 'pair4', 'pair2', 'pair16']
# 	[#] Round 5: key pair3
# 	[#] Round 5: key pair6
# 	[#] Round 5: key pair1
# 	[#] Round 5: key pair9
# 	[#] Round 5: key pair17
# 	[#] Round 5: key pair15
# 	[#] Round 5: key pair5
# 	[#] Round 5: key pair4
# 	[#] Round 5: key pair2
# 	[#] Round 5: key pair16
# [#] Round 6: keys_iters[0]:  ['pair9', 'pair1', 'pair15', 'pair12', 'pair14', 'pair19', 'pair4', 'pair13', 'pair3', 'pair7']
# 	[#] Round 6: key pair9
# 	[#] Round 6: key pair1
# 	[#] Round 6: key pair15
# 	[#] Round 6: key pair12
# 	[#] Round 6: key pair14
# 	[#] Round 6: key pair19
# 	[#] Round 6: key pair4
# 	[#] Round 6: key pair13
# 	[#] Round 6: key pair3
# 	[#] Round 6: key pair7
# [#] Round 6: keys_iters[1]:  ['pair18', 'pair6', 'pair20', 'pair17', 'pair5', 'pair16', 'pair11', 'pair2', 'pair8', 'pair10']
# 	[#] Round 6: key pair18
# 	[#] Round 6: key pair6
# 	[#] Round 6: key pair20
# 	[#] Round 6: key pair17
# 	[#] Round 6: key pair5
# 	[#] Round 6: key pair16
# 	[#] Round 6: key pair11
# 	[#] Round 6: key pair2
# 	[#] Round 6: key pair8
# 	[#] Round 6: key pair10
# [#] Round 7: keys_iters[0]:  ['pair4', 'pair1', 'pair8', 'pair5', 'pair6', 'pair19', 'pair13', 'pair20', 'pair12', 'pair15']
# 	[#] Round 7: key pair4
# 	[#] Round 7: key pair1
# 	[#] Round 7: key pair8
# 	[#] Round 7: key pair5
# 	[#] Round 7: key pair6
# 	[#] Round 7: key pair19
# 	[#] Round 7: key pair13
# 	[#] Round 7: key pair20
# 	[#] Round 7: key pair12
# 	[#] Round 7: key pair15
# [#] Round 7: keys_iters[1]:  ['pair7', 'pair9', 'pair18', 'pair17', 'pair10', 'pair11', 'pair14', 'pair16', 'pair3', 'pair2']
# 	[#] Round 7: key pair7
# 	[#] Round 7: key pair9
# 	[#] Round 7: key pair18
# 	[#] Round 7: key pair17
# 	[#] Round 7: key pair10
# 	[#] Round 7: key pair11
# 	[#] Round 7: key pair14
# 	[#] Round 7: key pair16
# 	[#] Round 7: key pair3
# 	[#] Round 7: key pair2
# [#] Round 8: keys_iters[0]:  ['pair3', 'pair5', 'pair9', 'pair16', 'pair15', 'pair14', 'pair6', 'pair8', 'pair2', 'pair20']
# 	[#] Round 8: key pair3
# 	[#] Round 8: key pair5
# 	[#] Round 8: key pair9
# 	[#] Round 8: key pair16
# 	[#] Round 8: key pair15
# 	[#] Round 8: key pair14
# 	[#] Round 8: key pair6
# 	[#] Round 8: key pair8
# 	[#] Round 8: key pair2
# 	[#] Round 8: key pair20
# [#] Round 8: keys_iters[1]:  ['pair19', 'pair13', 'pair1', 'pair18', 'pair10', 'pair12', 'pair17', 'pair4', 'pair7', 'pair11']
# 	[#] Round 8: key pair19
# 	[#] Round 8: key pair13
# 	[#] Round 8: key pair1
# 	[#] Round 8: key pair18
# 	[#] Round 8: key pair10
# 	[#] Round 8: key pair12
# 	[#] Round 8: key pair17
# 	[#] Round 8: key pair4
# 	[#] Round 8: key pair7
# 	[#] Round 8: key pair11
# [#] Round 9: keys_iters[0]:  ['pair18', 'pair14', 'pair19', 'pair10', 'pair6', 'pair1', 'pair9', 'pair17', 'pair5', 'pair13']
# 	[#] Round 9: key pair18
# 	[#] Round 9: key pair14
# 	[#] Round 9: key pair19
# 	[#] Round 9: key pair10
# 	[#] Round 9: key pair6
# 	[#] Round 9: key pair1
# 	[#] Round 9: key pair9
# 	[#] Round 9: key pair17
# 	[#] Round 9: key pair5
# 	[#] Round 9: key pair13
# [#] Round 9: keys_iters[1]:  ['pair20', 'pair16', 'pair4', 'pair12', 'pair8', 'pair15', 'pair3', 'pair11', 'pair7', 'pair2']
# 	[#] Round 9: key pair20
# 	[#] Round 9: key pair16
# 	[#] Round 9: key pair4
# 	[#] Round 9: key pair12
# 	[#] Round 9: key pair8
# 	[#] Round 9: key pair15
# 	[#] Round 9: key pair3
# 	[#] Round 9: key pair11
# 	[#] Round 9: key pair7
# 	[#] Round 9: key pair2
# [#] Total chunks:  20
# Total elements in all chunks:  100
# Example chunk:  [('pair11', 'difareli++-vs-hou22_geom'), ('pair15', 'difareli++-vs-ic_light'), ('pair19', 'difareli++-vs-diffusionrig'), ('pair5', 'difareli++-vs-relipa'), ('pair16', 'difareli++-vs-hou22_geom'), ('pair3', 'difareli++-vs-diffusionrig'), ('pair2', 'difareli++-vs-ic_light'), ('pair6', 'difareli++-vs-relipa'), ('pair10', 'difareli++-vs-relipa'), ('pair13', 'difareli++-vs-hou22_geom')]
# Example chunk:  [('pair14', 'difareli++-vs-diffusionrig'), ('pair12', 'difareli++-vs-relipa'), ('pair18', 'difareli++-vs-hou21_shadowm'), ('pair1', 'difareli++-vs-relipa'), ('pair4', 'difareli++-vs-relipa'), ('pair17', 'difareli++-vs-hou22_geom'), ('pair9', 'difareli++-vs-diffusionrig'), ('pair20', 'difareli++-vs-relipa'), ('pair7', 'difareli++-vs-diffusionrig'), ('pair8', 'difareli++-vs-hou22_geom')]
# Final sj_dict:  {'pair1': [], 'pair2': [], 'pair3': [], 'pair4': [], 'pair5': [], 'pair6': [], 'pair7': [], 'pair8': [], 'pair9': [], 'pair10': [], 'pair11': [], 'pair12': [], 'pair13': [], 'pair14': [], 'pair15': [], 'pair16': [], 'pair17': [], 'pair18': [], 'pair19': [], 'pair20': []}
