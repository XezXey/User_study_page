# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import json

data = pd.read_csv('./Batch_targetSH.csv')
df = data[['Input.sj_name', 'WorkTimeInSeconds', 'WorkerId', 'Answer.taskAnswers']]


out_q1 = {
    'difareli++': 0,
    'hou22_geom': 0,
    'hou21_shadowm': 0,
    'total_relighting': 0,
    'ic_light': 0,
}
out_q2 = {
    'difareli++': 0,
    'hou22_geom': 0,
    'hou21_shadowm': 0,
    'total_relighting': 0,
    'ic_light': 0,
}
for i in range(len(df)):
    answer = json.loads(df.iloc[i]['Answer.taskAnswers'])
    assert len(answer) == 1
    answer = answer[0]
    # print(list(answer.keys())[:20])
    # print(list(answer.keys())[20:])
    for a in list(answer.keys())[:20]:
        tmp = [x for x, y in answer[a].items() if y is True]
        if tmp == []:
            continue
        assert len(tmp) == 1
        qidx = int(a.split('_')[0][1:])
        user_ans = tmp[0][3:]
        assert qidx != 0
        if qidx % 2 != 0:
            out_q1[user_ans] += 1
        else: out_q2[user_ans] += 1
        
n_out_q1 = sum([v for v in out_q1.values()])
n_out_q2 = sum([v for v in out_q2.values()])

total = {}
for k in out_q1.keys():
    total[k] = out_q1[k] + out_q2[k]
    
print("Total q1 answer: ", n_out_q1)
print("Total q2 answer: ", n_out_q2)
print("="*100)
print("Answer: ")
print("Q1: ", out_q1)
print("Q2: ", out_q2)
print("Total: ", total)

perc_out_q1 = {k: v/n_out_q1 for k, v in out_q1.items()}
perc_out_q2 = {k: v/n_out_q2 for k, v in out_q2.items()}
perc_out_total = {k: v/(n_out_q1+n_out_q2) for k, v in total.items()}

print("="*100)
print("Percentage: ")
print("Q1: ", perc_out_q1)
print("Q2: ", perc_out_q2)
print("Total: ", perc_out_total)
# Out:
# Total q1 answer:  297
# Total q2 answer:  297
# ====================================================================================================
# Answer:
# Q1:  {'difareli++': 90, 'hou22_geom': 31, 'hou21_shadowm': 62, 'total_relighting': 40, 'ic_light': 74}
# Q2:  {'difareli++': 96, 'hou22_geom': 32, 'hou21_shadowm': 52, 'total_relighting': 43, 'ic_light': 74}
# Total:  {'difareli++': 186, 'hou22_geom': 63, 'hou21_shadowm': 114, 'total_relighting': 83, 'ic_light': 148}
# ====================================================================================================
# Percentage:
# Q1:  {'difareli++': 0.30303030303030304, 'hou22_geom': 0.10437710437710437, 'hou21_shadowm': 0.20875420875420875, 'total_relighting': 0.13468013468013468, 'ic_light': 0.24915824915824916}
# Q2:  {'difareli++': 0.32323232323232326, 'hou22_geom': 0.10774410774410774, 'hou21_shadowm': 0.1750841750841751, 'total_relighting': 0.1447811447811448, 'ic_light': 0.24915824915824916}
# Total:  {'difareli++': 0.31313131313131315, 'hou22_geom': 0.10606060606060606, 'hou21_shadowm': 0.1919191919191919, 'total_relighting': 0.13973063973063973, 'ic_light': 0.24915824915824916}

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import json

data = pd.read_csv('./Batch_rotateSH.csv')
df = data[['Input.sj_name', 'WorkTimeInSeconds', 'WorkerId', 'Answer.taskAnswers']]


out_q1 = {
    'difareli++': 0,
    'hou22_geom': 0,
    'hou21_shadowm': 0,
    'ic_light': 0,
}
out_q2 = {
    'difareli++': 0,
    'hou22_geom': 0,
    'hou21_shadowm': 0,
    'ic_light': 0,
}
for i in range(len(df)):
    answer = json.loads(df.iloc[i]['Answer.taskAnswers'])
    assert len(answer) == 1
    answer = answer[0]
    # print(list(answer.keys())[:20])
    # print(list(answer.keys())[20:])
    for a in list(answer.keys())[:20]:
        tmp = [x for x, y in answer[a].items() if y is True]
        if tmp == []:
            continue
        assert len(tmp) == 1
        qidx = int(a.split('_')[0][1:])
        user_ans = tmp[0][3:]
        assert qidx != 0
        if qidx % 2 != 0:
            out_q1[user_ans] += 1
        else: out_q2[user_ans] += 1
        
n_out_q1 = sum([v for v in out_q1.values()])
n_out_q2 = sum([v for v in out_q2.values()])

total = {}
for k in out_q1.keys():
    total[k] = out_q1[k] + out_q2[k]
    
print("Total q1 answer: ", n_out_q1)
print("Total q2 answer: ", n_out_q2)
print("="*100)
print("Answer: ")
print("Q1: ", out_q1)
print("Q2: ", out_q2)
print("Total: ", total)

perc_out_q1 = {k: v/n_out_q1 for k, v in out_q1.items()}
perc_out_q2 = {k: v/n_out_q2 for k, v in out_q2.items()}
perc_out_total = {k: v/(n_out_q1+n_out_q2) for k, v in total.items()}

print("="*100)
print("Percentage: ")
print("Q1: ", perc_out_q1)
print("Q2: ", perc_out_q2)
print("Total: ", perc_out_total)
# Out:
# Total q1 answer:  60
# Total q2 answer:  60
# ====================================================================================================
# Answer:
# Q1:  {'difareli++': 30, 'hou22_geom': 9, 'hou21_shadowm': 14, 'ic_light': 7}
# Q2:  {'difareli++': 42, 'hou22_geom': 5, 'hou21_shadowm': 5, 'ic_light': 8}
# Total:  {'difareli++': 72, 'hou22_geom': 14, 'hou21_shadowm': 19, 'ic_light': 15}
# ====================================================================================================
# Percentage:
# Q1:  {'difareli++': 0.5, 'hou22_geom': 0.15, 'hou21_shadowm': 0.23333333333333334, 'ic_light': 0.11666666666666667}
# Q2:  {'difareli++': 0.7, 'hou22_geom': 0.08333333333333333, 'hou21_shadowm': 0.08333333333333333, 'ic_light': 0.13333333333333333}
# Total:  {'difareli++': 0.6, 'hou22_geom': 0.11666666666666667, 'hou21_shadowm': 0.15833333333333333, 'ic_light': 0.125}
