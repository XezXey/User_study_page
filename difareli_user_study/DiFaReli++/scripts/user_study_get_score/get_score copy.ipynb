# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import json

data = pd.read_csv('./Batch_targetSH.csv')
df = data[['Input.sj_name', 'WorkTimeInSeconds', 'WorkerId', 'Answer.taskAnswers']]


out_q1 = {
    'difareli++': 0,
    'hou22_geom': 0,
    'hou21_shadowm': 0,
    'total_relighting': 0,
    'ic_light': 0,
}
out_q2 = {
    'difareli++': 0,
    'hou22_geom': 0,
    'hou21_shadowm': 0,
    'total_relighting': 0,
    'ic_light': 0,
}
for i in range(len(df)):
    answer = json.loads(df.iloc[i]['Answer.taskAnswers'])
    print(len(answer))
    print(answer)
    assert len(answer) == 1
    answer = answer[0]
    # print(list(answer.keys())[:20])
    # print(list(answer.keys())[20:])
    for a in list(answer.keys())[:20]:
        tmp = [x for x, y in answer[a].items() if y is True]
        if tmp == []:
            continue
        assert len(tmp) == 1
        qidx = int(a.split('_')[0][1:])
        user_ans = tmp[0][3:]
        assert qidx != 0
        if qidx % 2 != 0:
            out_q1[user_ans] += 1
        else: out_q2[user_ans] += 1
        
n_out_q1 = sum([v for v in out_q1.values()])
n_out_q2 = sum([v for v in out_q2.values()])

total = {}
for k in out_q1.keys():
    total[k] = out_q1[k] + out_q2[k]
    
print("Total q1 answer: ", n_out_q1)
print("Total q2 answer: ", n_out_q2)
print("="*100)
print("Answer: ")
print("Q1: ", out_q1)
print("Q2: ", out_q2)
print("Total: ", total)

perc_out_q1 = {k: v/n_out_q1 for k, v in out_q1.items()}
perc_out_q2 = {k: v/n_out_q2 for k, v in out_q2.items()}
perc_out_total = {k: v/(n_out_q1+n_out_q2) for k, v in total.items()}

print("="*100)
print("Percentage: ")
print("Q1: ", perc_out_q1)
print("Q2: ", perc_out_q2)
print("Total: ", perc_out_total)
# Out:
# 1
# [{'q10_p94': {'a1_hou21_shadowm': False, 'a2_hou22_geom': False, 'a3_difareli++': False, 'a4_total_relighting': True, 'a5_ic_light': False}, 'q11_p64': {'a1_hou21_shadowm': False, 'a2_difareli++': False, 'a3_ic_light': False, 'a4_total_relighting': True, 'a5_hou22_geom': False}, 'q12_p64': {'a1_hou21_shadowm': False, 'a2_difareli++': False, 'a3_ic_light': False, 'a4_total_relighting': True, 'a5_hou22_geom': False}, 'q13_p6': {'a1_hou22_geom': False, 'a2_difareli++': True, 'a3_total_relighting': False, 'a4_hou21_shadowm': False, 'a5_ic_light': False}, 'q14_p6': {'a1_hou22_geom': False, 'a2_difareli++': True, 'a3_total_relighting': False, 'a4_hou21_shadowm': False, 'a5_ic_light': False}, 'q15_p79': {'a1_hou21_shadowm': False, 'a2_difareli++': False, 'a3_ic_light': False, 'a4_hou22_geom': True, 'a5_total_relighting': False}, 'q16_p79': {'a1_hou21_shadowm': False, 'a2_difareli++': False, 'a3_ic_light': False, 'a4_hou22_geom': True, 'a5_total_relighting': False}, 'q17_p85': {'a1_hou22_geom': False, 'a2_ic_light': False, 'a3_total_relighting': False, 'a4_difareli++': True, 'a5_hou21_shadowm': False}, 'q18_p85': {'a1_hou22_geom': False, 'a2_ic_light': False, 'a3_total_relighting': False, 'a4_difareli++': True, 'a5_hou21_shadowm': False}, 'q19_p15': {'a1_hou22_geom': False, 'a2_hou21_shadowm': True, 'a3_difareli++': False, 'a4_ic_light': False, 'a5_total_relighting': False}, 'q1_p75': {'a1_hou21_shadowm': False, 'a2_hou22_geom': False, 'a3_difareli++': False, 'a4_ic_light': False, 'a5_total_relighting': True}, 'q20_p15': {'a1_hou22_geom': False, 'a2_hou21_shadowm': True, 'a3_difareli++': False, 'a4_ic_light': False, 'a5_total_relighting': False}, 'q2_p75': {'a1_hou21_shadowm': False, 'a2_hou22_geom': False, 'a3_difareli++': False, 'a4_ic_light': False, 'a5_total_relighting': True}, 'q3_p39': {'a1_hou22_geom': False, 'a2_hou21_shadowm': False, 'a3_difareli++': False, 'a4_total_relighting': False, 'a5_ic_light': True}, 'q4_p39': {'a1_hou22_geom': False, 'a2_hou21_shadowm': False, 'a3_difareli++': False, 'a4_total_relighting': False, 'a5_ic_light': True}, 'q5_p91': {'a1_ic_light': False, 'a2_difareli++': True, 'a3_hou22_geom': False, 'a4_hou21_shadowm': False, 'a5_total_relighting': False}, 'q6_p91': {'a1_ic_light': False, 'a2_difareli++': True, 'a3_hou22_geom': False, 'a4_hou21_shadowm': False, 'a5_total_relighting': False}, 'q7_p88': {'a1_hou22_geom': False, 'a2_difareli++': False, 'a3_ic_light': True, 'a4_hou21_shadowm': False, 'a5_total_relighting': False}, 'q8_p88': {'a1_hou22_geom': False, 'a2_difareli++': False, 'a3_ic_light': True, 'a4_hou21_shadowm': False, 'a5_total_relighting': False}, 'q9_p94': {'a1_hou21_shadowm': False, 'a2_hou22_geom': False, 'a3_difareli++': True, 'a4_total_relighting': False, 'a5_ic_light': False}, 'q{qnum}_p15': {'a{anum}_{name}': False}, 'q{qnum}_p39': {'a{anum}_{name}': False}, 'q{qnum}_p6': {'a{anum}_{name}': False}, 'q{qnum}_p64': {'a{anum}_{name}': False}, 'q{qnum}_p75': {'a{anum}_{name}': False}, 'q{qnum}_p79': {'a{anum}_{name}': False}, 'q{qnum}_p85': {'a{anum}_{name}': False}, 'q{qnum}_p88': {'a{anum}_{name}': False}, 'q{qnum}_p91': {'a{anum}_{name}': False}, 'q{qnum}_p94': {'a{anum}_{name}': False}, 'q{qnum}_p{p}': {'a{anum}_{name}': False}}]
# ['a4_total_relighting']
# ['a4_total_relighting']
# ['a4_total_relighting']
# ['a2_difareli++']
# ['a2_difareli++']
# ['a4_hou22_geom']
# ['a4_hou22_geom']
# ['a4_difareli++']
# ['a4_difareli++']
# ['a2_hou21_shadowm']
# ['a5_total_relighting']
# ['a2_hou21_shadowm']
# ['a5_total_relighting']
# ['a5_ic_light']
# ['a5_ic_light']
# ['a2_difareli++']
# ['a2_difareli++']
# ['a3_ic_light']
# ['a3_ic_light']
# ['a3_difareli++']
# 1
# [{'q10_p94': {'a1_hou22_geom': False, 'a2_hou21_shadowm': False, 'a3_total_relighting': True, 'a4_difareli++': False, 'a5_ic_light': False}, 'q11_p64': {'a1_ic_light': False, 'a2_hou21_shadowm': False, 'a3_hou22_geom': True, 'a4_total_relighting': False, 'a5_difareli++': False}, 'q12_p64': {'a1_ic_light': False, 'a2_hou21_shadowm': False, 'a3_hou22_geom': True, 'a4_total_relighting': False, 'a5_difareli++': False}, 'q13_p6': {'a1_total_relighting': False, 'a2_hou21_shadowm': False, 'a3_ic_light': False, 'a4_hou22_geom': True, 'a5_difareli++': False}, 'q14_p6': {'a1_total_relighting': False, 'a2_hou21_shadowm': False, 'a3_ic_light': False, 'a4_hou22_geom': True, 'a5_difareli++': False}, 'q15_p79': {'a1_difareli++': False, 'a2_hou22_geom': False, 'a3_ic_light': False, 'a4_hou21_shadowm': True, 'a5_total_relighting': False}, 'q16_p79': {'a1_difareli++': False, 'a2_hou22_geom': False, 'a3_ic_light': True, 'a4_hou21_shadowm': False, 'a5_total_relighting': False}, 'q17_p85': {'a1_hou22_geom': False, 'a2_difareli++': False, 'a3_hou21_shadowm': False, 'a4_total_relighting': True, 'a5_ic_light': False}, 'q18_p85': {'a1_hou22_geom': False, 'a2_difareli++': False, 'a3_hou21_shadowm': False, 'a4_total_relighting': True, 'a5_ic_light': False}, 'q19_p15': {'a1_hou22_geom': False, 'a2_ic_light': False, 'a3_hou21_shadowm': True, 'a4_total_relighting': False, 'a5_difareli++': False}, 'q1_p75': {'a1_difareli++': True, 'a2_hou21_shadowm': False, 'a3_hou22_geom': False, 'a4_ic_light': False, 'a5_total_relighting': False}, 'q20_p15': {'a1_hou22_geom': False, 'a2_ic_light': False, 'a3_hou21_shadowm': True, 'a4_total_relighting': False, 'a5_difareli++': False}, 'q2_p75': {'a1_difareli++': False, 'a2_hou21_shadowm': True, 'a3_hou22_geom': False, 'a4_ic_light': False, 'a5_total_relighting': False}, 'q3_p39': {'a1_difareli++': False, 'a2_hou21_shadowm': True, 'a3_total_relighting': False, 'a4_ic_light': False, 'a5_hou22_geom': False}, 'q4_p39': {'a1_difareli++': False, 'a2_hou21_shadowm': False, 'a3_total_relighting': True, 'a4_ic_light': False, 'a5_hou22_geom': False}, 'q5_p91': {'a1_hou21_shadowm': False, 'a2_difareli++': False, 'a3_ic_light': False, 'a4_hou22_geom': True, 'a5_total_relighting': False}, 'q6_p91': {'a1_hou21_shadowm': False, 'a2_difareli++': False, 'a3_ic_light': False, 'a4_hou22_geom': True, 'a5_total_relighting': False}, 'q7_p88': {'a1_hou22_geom': False, 'a2_hou21_shadowm': False, 'a3_difareli++': False, 'a4_total_relighting': False, 'a5_ic_light': True}, 'q8_p88': {'a1_hou22_geom': False, 'a2_hou21_shadowm': False, 'a3_difareli++': False, 'a4_total_relighting': False, 'a5_ic_light': True}, 'q9_p94': {'a1_hou22_geom': False, 'a2_hou21_shadowm': False, 'a3_total_relighting': True, 'a4_difareli++': False, 'a5_ic_light': False}, 'q{qnum}_p15': {'a{anum}_{name}': False}, 'q{qnum}_p39': {'a{anum}_{name}': False}, 'q{qnum}_p6': {'a{anum}_{name}': False}, 'q{qnum}_p64': {'a{anum}_{name}': False}, 'q{qnum}_p75': {'a{anum}_{name}': False}, 'q{qnum}_p79': {'a{anum}_{name}': False}, 'q{qnum}_p85': {'a{anum}_{name}': False}, 'q{qnum}_p88': {'a{anum}_{name}': False}, 'q{qnum}_p91': {'a{anum}_{name}': False}, 'q{qnum}_p94': {'a{anum}_{name}': False}, 'q{qnum}_p{p}': {'a{anum}_{name}': False}}]
# ['a3_total_relighting']
# ['a3_hou22_geom']
# ['a3_hou22_geom']
# ['a4_hou22_geom']
# ['a4_hou22_geom']
# ['a4_hou21_shadowm']
# ['a3_ic_light']
# ['a4_total_relighting']
# ['a4_total_relighting']
# ['a3_hou21_shadowm']
# ['a1_difareli++']
# ['a3_hou21_shadowm']
# ['a2_hou21_shadowm']
# ['a2_hou21_shadowm']
# ['a3_total_relighting']
# ['a4_hou22_geom']
# ['a4_hou22_geom']
# ['a5_ic_light']
# ['a5_ic_light']
# ['a3_total_relighting']
# 1
# [{'q10_p94': {'a1_hou22_geom': False, 'a2_ic_light': False, 'a3_difareli++': True, 'a4_hou21_shadowm': False, 'a5_total_relighting': False}, 'q11_p64': {'a1_hou21_shadowm': False, 'a2_hou22_geom': False, 'a3_difareli++': False, 'a4_ic_light': True, 'a5_total_relighting': False}, 'q12_p64': {'a1_hou21_shadowm': False, 'a2_hou22_geom': False, 'a3_difareli++': False, 'a4_ic_light': True, 'a5_total_relighting': False}, 'q13_p6': {'a1_hou21_shadowm': True, 'a2_difareli++': False, 'a3_hou22_geom': False, 'a4_ic_light': False, 'a5_total_relighting': False}, 'q14_p6': {'a1_hou21_shadowm': True, 'a2_difareli++': False, 'a3_hou22_geom': False, 'a4_ic_light': False, 'a5_total_relighting': False}, 'q15_p79': {'a1_ic_light': False, 'a2_hou21_shadowm': False, 'a3_total_relighting': False, 'a4_difareli++': True, 'a5_hou22_geom': False}, 'q16_p79': {'a1_ic_light': False, 'a2_hou21_shadowm': False, 'a3_total_relighting': False, 'a4_difareli++': True, 'a5_hou22_geom': False}, 'q17_p85': {'a1_hou22_geom': False, 'a2_difareli++': True, 'a3_hou21_shadowm': False, 'a4_total_relighting': False, 'a5_ic_light': False}, 'q18_p85': {'a1_hou22_geom': False, 'a2_difareli++': True, 'a3_hou21_shadowm': False, 'a4_total_relighting': False, 'a5_ic_light': False}, 'q19_p15': {'a1_difareli++': False, 'a2_hou22_geom': True, 'a3_ic_light': False, 'a4_hou21_shadowm': False, 'a5_total_relighting': False}, 'q1_p75': {'a1_ic_light': False, 'a2_hou22_geom': True, 'a3_total_relighting': False, 'a4_difareli++': False, 'a5_hou21_shadowm': False}, 'q20_p15': {'a1_difareli++': False, 'a2_hou22_geom': True, 'a3_ic_light': False, 'a4_hou21_shadowm': False, 'a5_total_relighting': False}, 'q2_p75': {'a1_ic_light': False, 'a2_hou22_geom': True, 'a3_total_relighting': False, 'a4_difareli++': False, 'a5_hou21_shadowm': False}, 'q3_p39': {'a1_total_relighting': False, 'a2_hou22_geom': False, 'a3_difareli++': True, 'a4_hou21_shadowm': False, 'a5_ic_light': False}, 'q4_p39': {'a1_total_relighting': False, 'a2_hou22_geom': False, 'a3_difareli++': True, 'a4_hou21_shadowm': False, 'a5_ic_light': False}, 'q5_p91': {'a1_hou22_geom': False, 'a2_ic_light': False, 'a3_difareli++': False, 'a4_total_relighting': True, 'a5_hou21_shadowm': False}, 'q6_p91': {'a1_hou22_geom': False, 'a2_ic_light': False, 'a3_difareli++': False, 'a4_total_relighting': True, 'a5_hou21_shadowm': False}, 'q7_p88': {'a1_difareli++': False, 'a2_hou21_shadowm': False, 'a3_total_relighting': False, 'a4_ic_light': True, 'a5_hou22_geom': False}, 'q8_p88': {'a1_difareli++': False, 'a2_hou21_shadowm': False, 'a3_total_relighting': False, 'a4_ic_light': True, 'a5_hou22_geom': False}, 'q9_p94': {'a1_hou22_geom': False, 'a2_ic_light': False, 'a3_difareli++': True, 'a4_hou21_shadowm': False, 'a5_total_relighting': False}, 'q{qnum}_p15': {'a{anum}_{name}': False}, 'q{qnum}_p39': {'a{anum}_{name}': False}, 'q{qnum}_p6': {'a{anum}_{name}': False}, 'q{qnum}_p64': {'a{anum}_{name}': False}, 'q{qnum}_p75': {'a{anum}_{name}': False}, 'q{qnum}_p79': {'a{anum}_{name}': False}, 'q{qnum}_p85': {'a{anum}_{name}': False}, 'q{qnum}_p88': {'a{anum}_{name}': False}, 'q{qnum}_p91': {'a{anum}_{name}': False}, 'q{qnum}_p94': {'a{anum}_{name}': False}, 'q{qnum}_p{p}': {'a{anum}_{name}': False}}]
# ['a3_difareli++']
# ['a4_ic_light']
# ['a4_ic_light']
# ['a1_hou21_shadowm']
# ['a1_hou21_shadowm']
# ['a4_difareli++']
# ['a4_difareli++']
# ['a2_difareli++']
# ['a2_difareli++']
# ['a2_hou22_geom']
# ['a2_hou22_geom']
# ['a2_hou22_geom']
# ['a2_hou22_geom']
# ['a3_difareli++']
# ['a3_difareli++']
# ['a4_total_relighting']
# ['a4_total_relighting']
# ['a4_ic_light']
# ['a4_ic_light']
# ['a3_difareli++']
# 1
# [{'q10_p89': {'a1_hou21_shadowm': False, 'a2_difareli++': False, 'a3_hou22_geom': True, 'a4_ic_light': False, 'a5_total_relighting': False}, 'q11_p31': {'a1_hou22_geom': False, 'a2_total_relighting': False, 'a3_difareli++': True, 'a4_ic_light': False, 'a5_hou21_shadowm': False}, 'q12_p31': {'a1_hou22_geom': False, 'a2_total_relighting': False, 'a3_difareli++': True, 'a4_ic_light': False, 'a5_hou21_shadowm': False}, 'q13_p86': {'a1_hou22_geom': False, 'a2_ic_light': True, 'a3_difareli++': False, 'a4_hou21_shadowm': False, 'a5_total_relighting': False}, 'q14_p86': {'a1_hou22_geom': False, 'a2_ic_light': False, 'a3_difareli++': True, 'a4_hou21_shadowm': False, 'a5_total_relighting': False}, 'q15_p55': {'a1_total_relighting': False, 'a2_ic_light': False, 'a3_hou21_shadowm': True, 'a4_difareli++': False, 'a5_hou22_geom': False}, 'q16_p55': {'a1_total_relighting': False, 'a2_ic_light': True, 'a3_hou21_shadowm': False, 'a4_difareli++': False, 'a5_hou22_geom': False}, 'q17_p1': {'a1_hou21_shadowm': False, 'a2_ic_light': False, 'a3_total_relighting': True, 'a4_difareli++': False, 'a5_hou22_geom': False}, 'q18_p1': {'a1_hou21_shadowm': False, 'a2_ic_light': True, 'a3_total_relighting': False, 'a4_difareli++': False, 'a5_hou22_geom': False}, 'q19_p87': {'a1_difareli++': False, 'a2_ic_light': True, 'a3_hou22_geom': False, 'a4_total_relighting': False, 'a5_hou21_shadowm': False}, 'q1_p2': {'a1_hou22_geom': False, 'a2_difareli++': True, 'a3_hou21_shadowm': False, 'a4_ic_light': False, 'a5_total_relighting': False}, 'q20_p87': {'a1_difareli++': False, 'a2_ic_light': False, 'a3_hou22_geom': True, 'a4_total_relighting': False, 'a5_hou21_shadowm': False}, 'q2_p2': {'a1_hou22_geom': False, 'a2_difareli++': False, 'a3_hou21_shadowm': True, 'a4_ic_light': False, 'a5_total_relighting': False}, 'q3_p40': {'a1_hou21_shadowm': False, 'a2_ic_light': False, 'a3_difareli++': True, 'a4_hou22_geom': False, 'a5_total_relighting': False}, 'q4_p40': {'a1_hou21_shadowm': False, 'a2_ic_light': True, 'a3_difareli++': False, 'a4_hou22_geom': False, 'a5_total_relighting': False}, 'q5_p18': {'a1_hou22_geom': False, 'a2_ic_light': False, 'a3_difareli++': True, 'a4_total_relighting': False, 'a5_hou21_shadowm': False}, 'q6_p18': {'a1_hou22_geom': False, 'a2_ic_light': False, 'a3_difareli++': True, 'a4_total_relighting': False, 'a5_hou21_shadowm': False}, 'q7_p61': {'a1_total_relighting': False, 'a2_ic_light': False, 'a3_hou21_shadowm': True, 'a4_hou22_geom': False, 'a5_difareli++': False}, 'q8_p61': {'a1_total_relighting': False, 'a2_ic_light': True, 'a3_hou21_shadowm': False, 'a4_hou22_geom': False, 'a5_difareli++': False}, 'q9_p89': {'a1_hou21_shadowm': True, 'a2_difareli++': False, 'a3_hou22_geom': False, 'a4_ic_light': False, 'a5_total_relighting': False}, 'q{qnum}_p1': {'a{anum}_{name}': False}, 'q{qnum}_p18': {'a{anum}_{name}': False}, 'q{qnum}_p2': {'a{anum}_{name}': False}, 'q{qnum}_p31': {'a{anum}_{name}': False}, 'q{qnum}_p40': {'a{anum}_{name}': False}, 'q{qnum}_p55': {'a{anum}_{name}': False}, 'q{qnum}_p61': {'a{anum}_{name}': False}, 'q{qnum}_p86': {'a{anum}_{name}': False}, 'q{qnum}_p87': {'a{anum}_{name}': False}, 'q{qnum}_p89': {'a{anum}_{name}': False}, 'q{qnum}_p{p}': {'a{anum}_{name}': False}}]
# ['a3_hou22_geom']
# ['a3_difareli++']
# ['a3_difareli++']
# ['a2_ic_light']
# ['a3_difareli++']
# ['a3_hou21_shadowm']
# ['a2_ic_light']
# ['a3_total_relighting']
# ['a2_ic_light']
# ['a2_ic_light']
# ['a2_difareli++']
# ['a3_hou22_geom']
# ['a3_hou21_shadowm']
# ['a3_difareli++']
# ['a2_ic_light']
# ['a3_difareli++']
# ['a3_difareli++']
# ['a3_hou21_shadowm']
# ['a2_ic_light']
# ['a1_hou21_shadowm']
# 1
# [{'q10_p89': {'a1_total_relighting': False, 'a2_ic_light': False, 'a3_hou22_geom': True, 'a4_difareli++': False, 'a5_hou21_shadowm': False}, 'q11_p31': {'a1_ic_light': False, 'a2_difareli++': False, 'a3_hou22_geom': True, 'a4_hou21_shadowm': False, 'a5_total_relighting': False}, 'q12_p31': {'a1_ic_light': False, 'a2_difareli++': False, 'a3_hou22_geom': True, 'a4_hou21_shadowm': False, 'a5_total_relighting': False}, 'q13_p86': {'a1_ic_light': False, 'a2_hou22_geom': False, 'a3_hou21_shadowm': True, 'a4_difareli++': False, 'a5_total_relighting': False}, 'q14_p86': {'a1_ic_light': False, 'a2_hou22_geom': False, 'a3_hou21_shadowm': True, 'a4_difareli++': False, 'a5_total_relighting': False}, 'q15_p55': {'a1_ic_light': False, 'a2_hou21_shadowm': False, 'a3_difareli++': True, 'a4_hou22_geom': False, 'a5_total_relighting': False}, 'q16_p55': {'a1_ic_light': False, 'a2_hou21_shadowm': False, 'a3_difareli++': False, 'a4_hou22_geom': True, 'a5_total_relighting': False}, 'q17_p1': {'a1_hou21_shadowm': False, 'a2_ic_light': False, 'a3_difareli++': False, 'a4_total_relighting': True, 'a5_hou22_geom': False}, 'q18_p1': {'a1_hou21_shadowm': False, 'a2_ic_light': False, 'a3_difareli++': False, 'a4_total_relighting': True, 'a5_hou22_geom': False}, 'q19_p87': {'a1_hou22_geom': False, 'a2_difareli++': False, 'a3_total_relighting': False, 'a4_hou21_shadowm': True, 'a5_ic_light': False}, 'q1_p2': {'a1_ic_light': False, 'a2_hou22_geom': False, 'a3_hou21_shadowm': True, 'a4_total_relighting': False, 'a5_difareli++': False}, 'q20_p87': {'a1_hou22_geom': False, 'a2_difareli++': False, 'a3_total_relighting': True, 'a4_hou21_shadowm': False, 'a5_ic_light': False}, 'q2_p2': {'a1_ic_light': False, 'a2_hou22_geom': False, 'a3_hou21_shadowm': True, 'a4_total_relighting': False, 'a5_difareli++': False}, 'q3_p40': {'a1_hou21_shadowm': False, 'a2_hou22_geom': False, 'a3_ic_light': True, 'a4_difareli++': False, 'a5_total_relighting': False}, 'q4_p40': {'a1_hou21_shadowm': False, 'a2_hou22_geom': False, 'a3_ic_light': True, 'a4_difareli++': False, 'a5_total_relighting': False}, 'q5_p18': {'a1_total_relighting': False, 'a2_ic_light': False, 'a3_hou21_shadowm': True, 'a4_difareli++': False, 'a5_hou22_geom': False}, 'q6_p18': {'a1_total_relighting': False, 'a2_ic_light': True, 'a3_hou21_shadowm': False, 'a4_difareli++': False, 'a5_hou22_geom': False}, 'q7_p61': {'a1_hou22_geom': False, 'a2_difareli++': False, 'a3_hou21_shadowm': True, 'a4_ic_light': False, 'a5_total_relighting': False}, 'q8_p61': {'a1_hou22_geom': False, 'a2_difareli++': False, 'a3_hou21_shadowm': True, 'a4_ic_light': False, 'a5_total_relighting': False}, 'q9_p89': {'a1_total_relighting': False, 'a2_ic_light': False, 'a3_hou22_geom': True, 'a4_difareli++': False, 'a5_hou21_shadowm': False}, 'q{qnum}_p1': {'a{anum}_{name}': False}, 'q{qnum}_p18': {'a{anum}_{name}': False}, 'q{qnum}_p2': {'a{anum}_{name}': False}, 'q{qnum}_p31': {'a{anum}_{name}': False}, 'q{qnum}_p40': {'a{anum}_{name}': False}, 'q{qnum}_p55': {'a{anum}_{name}': False}, 'q{qnum}_p61': {'a{anum}_{name}': False}, 'q{qnum}_p86': {'a{anum}_{name}': False}, 'q{qnum}_p87': {'a{anum}_{name}': False}, 'q{qnum}_p89': {'a{anum}_{name}': False}, 'q{qnum}_p{p}': {'a{anum}_{name}': False}}]
# ['a3_hou22_geom']
# ['a3_hou22_geom']
# ['a3_hou22_geom']
# ['a3_hou21_shadowm']
# ['a3_hou21_shadowm']
# ['a3_difareli++']
# ['a4_hou22_geom']
# ['a4_total_relighting']
# ['a4_total_relighting']
# ['a4_hou21_shadowm']
# ['a3_hou21_shadowm']
# ['a3_total_relighting']
# ['a3_hou21_shadowm']
# ['a3_ic_light']
# ['a3_ic_light']
# ['a3_hou21_shadowm']
# ['a2_ic_light']
# ['a3_hou21_shadowm']
# ['a3_hou21_shadowm']
# ['a3_hou22_geom']
# 1
# [{'q10_p89': {'a1_hou22_geom': False, 'a2_total_relighting': False, 'a3_difareli++': False, 'a4_hou21_shadowm': True, 'a5_ic_light': False}, 'q11_p31': {'a1_difareli++': False, 'a2_ic_light': False, 'a3_total_relighting': False, 'a4_hou21_shadowm': True, 'a5_hou22_geom': False}, 'q12_p31': {'a1_difareli++': False, 'a2_ic_light': False, 'a3_total_relighting': False, 'a4_hou21_shadowm': True, 'a5_hou22_geom': False}, 'q13_p86': {'a1_hou21_shadowm': False, 'a2_hou22_geom': True, 'a3_difareli++': False, 'a4_total_relighting': False, 'a5_ic_light': False}, 'q14_p86': {'a1_hou21_shadowm': False, 'a2_hou22_geom': False, 'a3_difareli++': True, 'a4_total_relighting': False, 'a5_ic_light': False}, 'q15_p55': {'a1_hou21_shadowm': False, 'a2_difareli++': True, 'a3_ic_light': False, 'a4_hou22_geom': False, 'a5_total_relighting': False}, 'q16_p55': {'a1_hou21_shadowm': False, 'a2_difareli++': False, 'a3_ic_light': False, 'a4_hou22_geom': False, 'a5_total_relighting': True}, 'q17_p1': {'a1_ic_light': False, 'a2_total_relighting': False, 'a3_hou22_geom': False, 'a4_difareli++': True, 'a5_hou21_shadowm': False}, 'q18_p1': {'a1_ic_light': False, 'a2_total_relighting': False, 'a3_hou22_geom': False, 'a4_difareli++': True, 'a5_hou21_shadowm': False}, 'q19_p87': {'a1_total_relighting': False, 'a2_hou21_shadowm': False, 'a3_hou22_geom': False, 'a4_difareli++': True, 'a5_ic_light': False}, 'q1_p2': {'a1_difareli++': False, 'a2_hou21_shadowm': False, 'a3_hou22_geom': False, 'a4_ic_light': True, 'a5_total_relighting': False}, 'q20_p87': {'a1_total_relighting': False, 'a2_hou21_shadowm': False, 'a3_hou22_geom': False, 'a4_difareli++': True, 'a5_ic_light': False}, 'q2_p2': {'a1_difareli++': False, 'a2_hou21_shadowm': False, 'a3_hou22_geom': False, 'a4_ic_light': True, 'a5_total_relighting': False}, 'q3_p40': {'a1_hou22_geom': False, 'a2_difareli++': True, 'a3_hou21_shadowm': False, 'a4_ic_light': False, 'a5_total_relighting': False}, 'q4_p40': {'a1_hou22_geom': False, 'a2_difareli++': False, 'a3_hou21_shadowm': True, 'a4_ic_light': False, 'a5_total_relighting': False}, 'q5_p18': {'a1_difareli++': False, 'a2_hou21_shadowm': False, 'a3_hou22_geom': False, 'a4_total_relighting': True, 'a5_ic_light': False}, 'q6_p18': {'a1_difareli++': False, 'a2_hou21_shadowm': False, 'a3_hou22_geom': False, 'a4_total_relighting': True, 'a5_ic_light': False}, 'q7_p61': {'a1_difareli++': False, 'a2_hou22_geom': True, 'a3_hou21_shadowm': False, 'a4_ic_light': False, 'a5_total_relighting': False}, 'q8_p61': {'a1_difareli++': False, 'a2_hou22_geom': False, 'a3_hou21_shadowm': True, 'a4_ic_light': False, 'a5_total_relighting': False}, 'q9_p89': {'a1_hou22_geom': False, 'a2_total_relighting': False, 'a3_difareli++': False, 'a4_hou21_shadowm': True, 'a5_ic_light': False}, 'q{qnum}_p1': {'a{anum}_{name}': False}, 'q{qnum}_p18': {'a{anum}_{name}': False}, 'q{qnum}_p2': {'a{anum}_{name}': False}, 'q{qnum}_p31': {'a{anum}_{name}': False}, 'q{qnum}_p40': {'a{anum}_{name}': False}, 'q{qnum}_p55': {'a{anum}_{name}': False}, 'q{qnum}_p61': {'a{anum}_{name}': False}, 'q{qnum}_p86': {'a{anum}_{name}': False}, 'q{qnum}_p87': {'a{anum}_{name}': False}, 'q{qnum}_p89': {'a{anum}_{name}': False}, 'q{qnum}_p{p}': {'a{anum}_{name}': False}}]
# ['a4_hou21_shadowm']
# ['a4_hou21_shadowm']
# ['a4_hou21_shadowm']
# ['a2_hou22_geom']
# ['a3_difareli++']
# ['a2_difareli++']
# ['a5_total_relighting']
# ['a4_difareli++']
# ['a4_difareli++']
# ['a4_difareli++']
# ['a4_ic_light']
# ['a4_difareli++']
# ['a4_ic_light']
# ['a2_difareli++']
# ['a3_hou21_shadowm']
# ['a4_total_relighting']
# ['a4_total_relighting']
# ['a2_hou22_geom']
# ['a3_hou21_shadowm']
# ['a4_hou21_shadowm']
# 1
# [{'q10_p19': {'a1_hou21_shadowm': False, 'a2_difareli++': True, 'a3_hou22_geom': False, 'a4_ic_light': False, 'a5_total_relighting': False}, 'q11_p71': {'a1_ic_light': False, 'a2_difareli++': False, 'a3_hou21_shadowm': True, 'a4_total_relighting': False, 'a5_hou22_geom': False}, 'q12_p71': {'a1_ic_light': False, 'a2_difareli++': True, 'a3_hou21_shadowm': False, 'a4_total_relighting': False, 'a5_hou22_geom': False}, 'q13_p33': {'a1_total_relighting': False, 'a2_hou22_geom': False, 'a3_difareli++': False, 'a4_hou21_shadowm': True, 'a5_ic_light': False}, 'q14_p33': {'a1_total_relighting': False, 'a2_hou22_geom': False, 'a3_difareli++': True, 'a4_hou21_shadowm': False, 'a5_ic_light': False}, 'q15_p59': {'a1_hou22_geom': False, 'a2_total_relighting': False, 'a3_difareli++': True, 'a4_hou21_shadowm': False, 'a5_ic_light': False}, 'q16_p59': {'a1_hou22_geom': False, 'a2_total_relighting': False, 'a3_difareli++': False, 'a4_hou21_shadowm': True, 'a5_ic_light': False}, 'q17_p30': {'a1_hou22_geom': False, 'a2_hou21_shadowm': True, 'a3_ic_light': False, 'a4_total_relighting': False, 'a5_difareli++': False}, 'q18_p30': {'a1_hou22_geom': False, 'a2_hou21_shadowm': False, 'a3_ic_light': False, 'a4_total_relighting': True, 'a5_difareli++': False}, 'q19_p98': {'a1_hou22_geom': False, 'a2_difareli++': True, 'a3_ic_light': False, 'a4_total_relighting': False, 'a5_hou21_shadowm': False}, 'q1_p13': {'a1_difareli++': False, 'a2_hou21_shadowm': True, 'a3_total_relighting': False, 'a4_hou22_geom': False, 'a5_ic_light': False}, 'q20_p98': {'a1_hou22_geom': False, 'a2_difareli++': True, 'a3_ic_light': False, 'a4_total_relighting': False, 'a5_hou21_shadowm': False}, 'q2_p13': {'a1_difareli++': False, 'a2_hou21_shadowm': True, 'a3_total_relighting': False, 'a4_hou22_geom': False, 'a5_ic_light': False}, 'q3_p96': {'a1_difareli++': False, 'a2_hou22_geom': False, 'a3_total_relighting': True, 'a4_hou21_shadowm': False, 'a5_ic_light': False}, 'q4_p96': {'a1_difareli++': False, 'a2_hou22_geom': False, 'a3_total_relighting': False, 'a4_hou21_shadowm': True, 'a5_ic_light': False}, 'q5_p92': {'a1_difareli++': False, 'a2_hou22_geom': False, 'a3_hou21_shadowm': False, 'a4_ic_light': True, 'a5_total_relighting': False}, 'q6_p92': {'a1_difareli++': True, 'a2_hou22_geom': False, 'a3_hou21_shadowm': False, 'a4_ic_light': False, 'a5_total_relighting': False}, 'q7_p25': {'a1_difareli++': True, 'a2_hou22_geom': False, 'a3_ic_light': False, 'a4_hou21_shadowm': False, 'a5_total_relighting': False}, 'q8_p25': {'a1_difareli++': True, 'a2_hou22_geom': False, 'a3_ic_light': False, 'a4_hou21_shadowm': False, 'a5_total_relighting': False}, 'q9_p19': {'a1_hou21_shadowm': False, 'a2_difareli++': True, 'a3_hou22_geom': False, 'a4_ic_light': False, 'a5_total_relighting': False}, 'q{qnum}_p13': {'a{anum}_{name}': False}, 'q{qnum}_p19': {'a{anum}_{name}': False}, 'q{qnum}_p25': {'a{anum}_{name}': False}, 'q{qnum}_p30': {'a{anum}_{name}': False}, 'q{qnum}_p33': {'a{anum}_{name}': False}, 'q{qnum}_p59': {'a{anum}_{name}': False}, 'q{qnum}_p71': {'a{anum}_{name}': False}, 'q{qnum}_p92': {'a{anum}_{name}': False}, 'q{qnum}_p96': {'a{anum}_{name}': False}, 'q{qnum}_p98': {'a{anum}_{name}': False}, 'q{qnum}_p{p}': {'a{anum}_{name}': False}}]
# ['a2_difareli++']
# ['a3_hou21_shadowm']
# ['a2_difareli++']
# ['a4_hou21_shadowm']
# ['a3_difareli++']
# ['a3_difareli++']
# ['a4_hou21_shadowm']
# ['a2_hou21_shadowm']
# ['a4_total_relighting']
# ['a2_difareli++']
# ['a2_hou21_shadowm']
# ['a2_difareli++']
# ['a2_hou21_shadowm']
# ['a3_total_relighting']
# ['a4_hou21_shadowm']
# ['a4_ic_light']
# ['a1_difareli++']
# ['a1_difareli++']
# ['a1_difareli++']
# ['a2_difareli++']
# 1
# [{'q10_p19': {'a1_hou22_geom': False, 'a2_difareli++': False, 'a3_total_relighting': True, 'a4_hou21_shadowm': False, 'a5_ic_light': False}, 'q11_p71': {'a1_total_relighting': True, 'a2_ic_light': False, 'a3_hou22_geom': False, 'a4_difareli++': False, 'a5_hou21_shadowm': False}, 'q12_p71': {'a1_total_relighting': False, 'a2_ic_light': False, 'a3_hou22_geom': True, 'a4_difareli++': False, 'a5_hou21_shadowm': False}, 'q13_p33': {'a1_ic_light': True, 'a2_hou21_shadowm': False, 'a3_total_relighting': False, 'a4_difareli++': False, 'a5_hou22_geom': False}, 'q14_p33': {'a1_ic_light': True, 'a2_hou21_shadowm': False, 'a3_total_relighting': False, 'a4_difareli++': False, 'a5_hou22_geom': False}, 'q15_p59': {'a1_ic_light': False, 'a2_total_relighting': False, 'a3_difareli++': False, 'a4_hou22_geom': True, 'a5_hou21_shadowm': False}, 'q16_p59': {'a1_ic_light': False, 'a2_total_relighting': False, 'a3_difareli++': False, 'a4_hou22_geom': True, 'a5_hou21_shadowm': False}, 'q17_p30': {'a1_ic_light': False, 'a2_total_relighting': False, 'a3_hou21_shadowm': True, 'a4_difareli++': False, 'a5_hou22_geom': False}, 'q18_p30': {'a1_ic_light': False, 'a2_total_relighting': False, 'a3_hou21_shadowm': True, 'a4_difareli++': False, 'a5_hou22_geom': False}, 'q19_p98': {'a1_total_relighting': False, 'a2_ic_light': False, 'a3_hou21_shadowm': True, 'a4_difareli++': False, 'a5_hou22_geom': False}, 'q1_p13': {'a1_difareli++': False, 'a2_hou22_geom': False, 'a3_total_relighting': False, 'a4_hou21_shadowm': True, 'a5_ic_light': False}, 'q20_p98': {'a1_total_relighting': False, 'a2_ic_light': False, 'a3_hou21_shadowm': False, 'a4_difareli++': True, 'a5_hou22_geom': False}, 'q2_p13': {'a1_difareli++': False, 'a2_hou22_geom': False, 'a3_total_relighting': True, 'a4_hou21_shadowm': False, 'a5_ic_light': False}, 'q3_p96': {'a1_hou21_shadowm': False, 'a2_total_relighting': False, 'a3_ic_light': True, 'a4_difareli++': False, 'a5_hou22_geom': False}, 'q4_p96': {'a1_hou21_shadowm': False, 'a2_total_relighting': False, 'a3_ic_light': True, 'a4_difareli++': False, 'a5_hou22_geom': False}, 'q5_p92': {'a1_ic_light': False, 'a2_hou22_geom': True, 'a3_hou21_shadowm': False, 'a4_total_relighting': False, 'a5_difareli++': False}, 'q6_p92': {'a1_ic_light': True, 'a2_hou22_geom': False, 'a3_hou21_shadowm': False, 'a4_total_relighting': False, 'a5_difareli++': False}, 'q7_p25': {'a1_ic_light': False, 'a2_difareli++': False, 'a3_hou22_geom': False, 'a4_hou21_shadowm': True, 'a5_total_relighting': False}, 'q8_p25': {'a1_ic_light': False, 'a2_difareli++': False, 'a3_hou22_geom': True, 'a4_hou21_shadowm': False, 'a5_total_relighting': False}, 'q9_p19': {'a1_hou22_geom': True, 'a2_difareli++': False, 'a3_total_relighting': False, 'a4_hou21_shadowm': False, 'a5_ic_light': False}, 'q{qnum}_p13': {'a{anum}_{name}': False}, 'q{qnum}_p19': {'a{anum}_{name}': False}, 'q{qnum}_p25': {'a{anum}_{name}': False}, 'q{qnum}_p30': {'a{anum}_{name}': False}, 'q{qnum}_p33': {'a{anum}_{name}': False}, 'q{qnum}_p59': {'a{anum}_{name}': False}, 'q{qnum}_p71': {'a{anum}_{name}': False}, 'q{qnum}_p92': {'a{anum}_{name}': False}, 'q{qnum}_p96': {'a{anum}_{name}': False}, 'q{qnum}_p98': {'a{anum}_{name}': False}, 'q{qnum}_p{p}': {'a{anum}_{name}': False}}]
# ['a3_total_relighting']
# ['a1_total_relighting']
# ['a3_hou22_geom']
# ['a1_ic_light']
# ['a1_ic_light']
# ['a4_hou22_geom']
# ['a4_hou22_geom']
# ['a3_hou21_shadowm']
# ['a3_hou21_shadowm']
# ['a3_hou21_shadowm']
# ['a4_hou21_shadowm']
# ['a4_difareli++']
# ['a3_total_relighting']
# ['a3_ic_light']
# ['a3_ic_light']
# ['a2_hou22_geom']
# ['a1_ic_light']
# ['a4_hou21_shadowm']
# ['a3_hou22_geom']
# ['a1_hou22_geom']
# 1
# [{'q10_p19': {'a1_hou22_geom': False, 'a2_total_relighting': True, 'a3_difareli++': False, 'a4_hou21_shadowm': False, 'a5_ic_light': False}, 'q11_p71': {'a1_hou21_shadowm': False, 'a2_total_relighting': False, 'a3_ic_light': True, 'a4_difareli++': False, 'a5_hou22_geom': False}, 'q12_p71': {'a1_hou21_shadowm': False, 'a2_total_relighting': False, 'a3_ic_light': True, 'a4_difareli++': False, 'a5_hou22_geom': False}, 'q13_p33': {'a1_hou21_shadowm': True, 'a2_difareli++': False, 'a3_ic_light': False, 'a4_hou22_geom': False, 'a5_total_relighting': False}, 'q14_p33': {'a1_hou21_shadowm': True, 'a2_difareli++': False, 'a3_ic_light': False, 'a4_hou22_geom': False, 'a5_total_relighting': False}, 'q15_p59': {'a1_hou22_geom': False, 'a2_difareli++': False, 'a3_hou21_shadowm': False, 'a4_total_relighting': True, 'a5_ic_light': False}, 'q16_p59': {'a1_hou22_geom': False, 'a2_difareli++': False, 'a3_hou21_shadowm': False, 'a4_total_relighting': True, 'a5_ic_light': False}, 'q17_p30': {'a1_ic_light': False, 'a2_hou21_shadowm': False, 'a3_difareli++': True, 'a4_total_relighting': False, 'a5_hou22_geom': False}, 'q18_p30': {'a1_ic_light': False, 'a2_hou21_shadowm': False, 'a3_difareli++': True, 'a4_total_relighting': False, 'a5_hou22_geom': False}, 'q19_p98': {'a1_difareli++': False, 'a2_ic_light': True, 'a3_hou22_geom': False, 'a4_total_relighting': False, 'a5_hou21_shadowm': False}, 'q1_p13': {'a1_ic_light': False, 'a2_hou22_geom': False, 'a3_total_relighting': False, 'a4_difareli++': True, 'a5_hou21_shadowm': False}, 'q20_p98': {'a1_difareli++': False, 'a2_ic_light': True, 'a3_hou22_geom': False, 'a4_total_relighting': False, 'a5_hou21_shadowm': False}, 'q2_p13': {'a1_ic_light': False, 'a2_hou22_geom': False, 'a3_total_relighting': False, 'a4_difareli++': True, 'a5_hou21_shadowm': False}, 'q3_p96': {'a1_total_relighting': False, 'a2_difareli++': False, 'a3_hou22_geom': False, 'a4_ic_light': True, 'a5_hou21_shadowm': False}, 'q4_p96': {'a1_total_relighting': False, 'a2_difareli++': False, 'a3_hou22_geom': False, 'a4_ic_light': True, 'a5_hou21_shadowm': False}, 'q5_p92': {'a1_hou21_shadowm': False, 'a2_hou22_geom': False, 'a3_total_relighting': False, 'a4_difareli++': False, 'a5_ic_light': True}, 'q6_p92': {'a1_hou21_shadowm': False, 'a2_hou22_geom': False, 'a3_total_relighting': False, 'a4_difareli++': False, 'a5_ic_light': True}, 'q7_p25': {'a1_hou21_shadowm': False, 'a2_difareli++': True, 'a3_ic_light': False, 'a4_hou22_geom': False, 'a5_total_relighting': False}, 'q8_p25': {'a1_hou21_shadowm': False, 'a2_difareli++': True, 'a3_ic_light': False, 'a4_hou22_geom': False, 'a5_total_relighting': False}, 'q9_p19': {'a1_hou22_geom': False, 'a2_total_relighting': True, 'a3_difareli++': False, 'a4_hou21_shadowm': False, 'a5_ic_light': False}, 'q{qnum}_p13': {'a{anum}_{name}': False}, 'q{qnum}_p19': {'a{anum}_{name}': False}, 'q{qnum}_p25': {'a{anum}_{name}': False}, 'q{qnum}_p30': {'a{anum}_{name}': False}, 'q{qnum}_p33': {'a{anum}_{name}': False}, 'q{qnum}_p59': {'a{anum}_{name}': False}, 'q{qnum}_p71': {'a{anum}_{name}': False}, 'q{qnum}_p92': {'a{anum}_{name}': False}, 'q{qnum}_p96': {'a{anum}_{name}': False}, 'q{qnum}_p98': {'a{anum}_{name}': False}, 'q{qnum}_p{p}': {'a{anum}_{name}': False}}]
# ['a2_total_relighting']
# ['a3_ic_light']
# ['a3_ic_light']
# ['a1_hou21_shadowm']
# ['a1_hou21_shadowm']
# ['a4_total_relighting']
# ['a4_total_relighting']
# ['a3_difareli++']
# ['a3_difareli++']
# ['a2_ic_light']
# ['a4_difareli++']
# ['a2_ic_light']
# ['a4_difareli++']
# ['a4_ic_light']
# ['a4_ic_light']
# ['a5_ic_light']
# ['a5_ic_light']
# ['a2_difareli++']
# ['a2_difareli++']
# ['a2_total_relighting']
# 1
# [{'q10_p38': {'a1_hou22_geom': False, 'a2_total_relighting': False, 'a3_difareli++': False, 'a4_hou21_shadowm': True, 'a5_ic_light': False}, 'q11_p47': {'a1_hou22_geom': False, 'a2_total_relighting': True, 'a3_difareli++': False, 'a4_hou21_shadowm': False, 'a5_ic_light': False}, 'q12_p47': {'a1_hou22_geom': False, 'a2_total_relighting': True, 'a3_difareli++': False, 'a4_hou21_shadowm': False, 'a5_ic_light': False}, 'q13_p41': {'a1_total_relighting': False, 'a2_hou21_shadowm': False, 'a3_ic_light': True, 'a4_hou22_geom': False, 'a5_difareli++': False}, 'q14_p41': {'a1_total_relighting': False, 'a2_hou21_shadowm': False, 'a3_ic_light': True, 'a4_hou22_geom': False, 'a5_difareli++': False}, 'q15_p78': {'a1_hou21_shadowm': False, 'a2_difareli++': False, 'a3_ic_light': True, 'a4_hou22_geom': False, 'a5_total_relighting': False}, 'q16_p78': {'a1_hou21_shadowm': False, 'a2_difareli++': False, 'a3_ic_light': True, 'a4_hou22_geom': False, 'a5_total_relighting': False}, 'q17_p70': {'a1_total_relighting': False, 'a2_hou21_shadowm': False, 'a3_difareli++': False, 'a4_hou22_geom': False, 'a5_ic_light': True}, 'q18_p70': {'a1_total_relighting': False, 'a2_hou21_shadowm': False, 'a3_difareli++': False, 'a4_hou22_geom': False, 'a5_ic_light': True}, 'q19_p77': {'a1_hou21_shadowm': False, 'a2_difareli++': True, 'a3_total_relighting': False, 'a4_ic_light': False, 'a5_hou22_geom': False}, 'q1_p50': {'a1_hou22_geom': True, 'a2_difareli++': False, 'a3_total_relighting': False, 'a4_hou21_shadowm': False, 'a5_ic_light': False}, 'q20_p77': {'a1_hou21_shadowm': False, 'a2_difareli++': True, 'a3_total_relighting': False, 'a4_ic_light': False, 'a5_hou22_geom': False}, 'q2_p50': {'a1_hou22_geom': False, 'a2_difareli++': True, 'a3_total_relighting': False, 'a4_hou21_shadowm': False, 'a5_ic_light': False}, 'q3_p48': {'a1_ic_light': False, 'a2_hou22_geom': True, 'a3_total_relighting': False, 'a4_difareli++': False, 'a5_hou21_shadowm': False}, 'q4_p48': {'a1_ic_light': False, 'a2_hou22_geom': True, 'a3_total_relighting': False, 'a4_difareli++': False, 'a5_hou21_shadowm': False}, 'q5_p26': {'a1_total_relighting': False, 'a2_ic_light': True, 'a3_hou21_shadowm': False, 'a4_difareli++': False, 'a5_hou22_geom': False}, 'q6_p26': {'a1_total_relighting': False, 'a2_ic_light': True, 'a3_hou21_shadowm': False, 'a4_difareli++': False, 'a5_hou22_geom': False}, 'q7_p16': {'a1_total_relighting': False, 'a2_ic_light': True, 'a3_hou22_geom': False, 'a4_difareli++': False, 'a5_hou21_shadowm': False}, 'q8_p16': {'a1_total_relighting': False, 'a2_ic_light': True, 'a3_hou22_geom': False, 'a4_difareli++': False, 'a5_hou21_shadowm': False}, 'q9_p38': {'a1_hou22_geom': False, 'a2_total_relighting': False, 'a3_difareli++': False, 'a4_hou21_shadowm': True, 'a5_ic_light': False}, 'q{qnum}_p16': {'a{anum}_{name}': False}, 'q{qnum}_p26': {'a{anum}_{name}': False}, 'q{qnum}_p38': {'a{anum}_{name}': False}, 'q{qnum}_p41': {'a{anum}_{name}': False}, 'q{qnum}_p47': {'a{anum}_{name}': False}, 'q{qnum}_p48': {'a{anum}_{name}': False}, 'q{qnum}_p50': {'a{anum}_{name}': False}, 'q{qnum}_p70': {'a{anum}_{name}': False}, 'q{qnum}_p77': {'a{anum}_{name}': False}, 'q{qnum}_p78': {'a{anum}_{name}': False}, 'q{qnum}_p{p}': {'a{anum}_{name}': False}}]
# ['a4_hou21_shadowm']
# ['a2_total_relighting']
# ['a2_total_relighting']
# ['a3_ic_light']
# ['a3_ic_light']
# ['a3_ic_light']
# ['a3_ic_light']
# ['a5_ic_light']
# ['a5_ic_light']
# ['a2_difareli++']
# ['a1_hou22_geom']
# ['a2_difareli++']
# ['a2_difareli++']
# ['a2_hou22_geom']
# ['a2_hou22_geom']
# ['a2_ic_light']
# ['a2_ic_light']
# ['a2_ic_light']
# ['a2_ic_light']
# ['a4_hou21_shadowm']
# 1
# [{'q10_p38': {'a1_hou22_geom': False, 'a2_hou21_shadowm': False, 'a3_difareli++': True, 'a4_ic_light': False, 'a5_total_relighting': False}, 'q11_p47': {'a1_difareli++': False, 'a2_hou22_geom': False, 'a3_ic_light': True, 'a4_hou21_shadowm': False, 'a5_total_relighting': False}, 'q12_p47': {'a1_difareli++': False, 'a2_hou22_geom': False, 'a3_ic_light': True, 'a4_hou21_shadowm': False, 'a5_total_relighting': False}, 'q13_p41': {'a1_difareli++': False, 'a2_hou22_geom': False, 'a3_hou21_shadowm': False, 'a4_ic_light': False, 'a5_total_relighting': True}, 'q14_p41': {'a1_difareli++': False, 'a2_hou22_geom': False, 'a3_hou21_shadowm': False, 'a4_ic_light': False, 'a5_total_relighting': True}, 'q15_p78': {'a1_hou22_geom': False, 'a2_difareli++': False, 'a3_hou21_shadowm': True, 'a4_total_relighting': False, 'a5_ic_light': False}, 'q16_p78': {'a1_hou22_geom': False, 'a2_difareli++': False, 'a3_hou21_shadowm': True, 'a4_total_relighting': False, 'a5_ic_light': False}, 'q17_p70': {'a1_total_relighting': False, 'a2_hou21_shadowm': False, 'a3_difareli++': True, 'a4_ic_light': False, 'a5_hou22_geom': False}, 'q18_p70': {'a1_total_relighting': False, 'a2_hou21_shadowm': False, 'a3_difareli++': False, 'a4_ic_light': True, 'a5_hou22_geom': False}, 'q19_p77': {'a1_hou21_shadowm': False, 'a2_hou22_geom': False, 'a3_ic_light': False, 'a4_total_relighting': True, 'a5_difareli++': False}, 'q1_p50': {'a1_difareli++': False, 'a2_ic_light': False, 'a3_hou21_shadowm': True, 'a4_hou22_geom': False, 'a5_total_relighting': False}, 'q20_p77': {'a1_hou21_shadowm': False, 'a2_hou22_geom': False, 'a3_ic_light': False, 'a4_total_relighting': True, 'a5_difareli++': False}, 'q2_p50': {'a1_difareli++': False, 'a2_ic_light': False, 'a3_hou21_shadowm': True, 'a4_hou22_geom': False, 'a5_total_relighting': False}, 'q3_p48': {'a1_hou22_geom': False, 'a2_difareli++': True, 'a3_hou21_shadowm': False, 'a4_ic_light': False, 'a5_total_relighting': False}, 'q4_p48': {'a1_hou22_geom': False, 'a2_difareli++': True, 'a3_hou21_shadowm': False, 'a4_ic_light': False, 'a5_total_relighting': False}, 'q5_p26': {'a1_total_relighting': False, 'a2_hou22_geom': False, 'a3_difareli++': False, 'a4_hou21_shadowm': True, 'a5_ic_light': False}, 'q6_p26': {'a1_total_relighting': False, 'a2_hou22_geom': True, 'a3_difareli++': False, 'a4_hou21_shadowm': False, 'a5_ic_light': False}, 'q7_p16': {'a1_ic_light': True, 'a2_hou22_geom': False, 'a3_hou21_shadowm': False, 'a4_difareli++': False, 'a5_total_relighting': False}, 'q8_p16': {'a1_ic_light': True, 'a2_hou22_geom': False, 'a3_hou21_shadowm': False, 'a4_difareli++': False, 'a5_total_relighting': False}, 'q9_p38': {'a1_hou22_geom': False, 'a2_hou21_shadowm': True, 'a3_difareli++': False, 'a4_ic_light': False, 'a5_total_relighting': False}, 'q{qnum}_p16': {'a{anum}_{name}': False}, 'q{qnum}_p26': {'a{anum}_{name}': False}, 'q{qnum}_p38': {'a{anum}_{name}': False}, 'q{qnum}_p41': {'a{anum}_{name}': False}, 'q{qnum}_p47': {'a{anum}_{name}': False}, 'q{qnum}_p48': {'a{anum}_{name}': False}, 'q{qnum}_p50': {'a{anum}_{name}': False}, 'q{qnum}_p70': {'a{anum}_{name}': False}, 'q{qnum}_p77': {'a{anum}_{name}': False}, 'q{qnum}_p78': {'a{anum}_{name}': False}, 'q{qnum}_p{p}': {'a{anum}_{name}': False}}]
# ['a3_difareli++']
# ['a3_ic_light']
# ['a3_ic_light']
# ['a5_total_relighting']
# ['a5_total_relighting']
# ['a3_hou21_shadowm']
# ['a3_hou21_shadowm']
# ['a3_difareli++']
# ['a4_ic_light']
# ['a4_total_relighting']
# ['a3_hou21_shadowm']
# ['a4_total_relighting']
# ['a3_hou21_shadowm']
# ['a2_difareli++']
# ['a2_difareli++']
# ['a4_hou21_shadowm']
# ['a2_hou22_geom']
# ['a1_ic_light']
# ['a1_ic_light']
# ['a2_hou21_shadowm']
# 1
# [{'q10_p38': {'a1_hou21_shadowm': False, 'a2_difareli++': False, 'a3_total_relighting': False, 'a4_ic_light': True, 'a5_hou22_geom': False}, 'q11_p47': {'a1_hou22_geom': False, 'a2_difareli++': False, 'a3_hou21_shadowm': False, 'a4_ic_light': True, 'a5_total_relighting': False}, 'q12_p47': {'a1_hou22_geom': False, 'a2_difareli++': False, 'a3_hou21_shadowm': False, 'a4_ic_light': True, 'a5_total_relighting': False}, 'q13_p41': {'a1_ic_light': True, 'a2_hou21_shadowm': False, 'a3_total_relighting': False, 'a4_difareli++': False, 'a5_hou22_geom': False}, 'q14_p41': {'a1_ic_light': True, 'a2_hou21_shadowm': False, 'a3_total_relighting': False, 'a4_difareli++': False, 'a5_hou22_geom': False}, 'q15_p78': {'a1_total_relighting': False, 'a2_ic_light': True, 'a3_hou21_shadowm': False, 'a4_difareli++': False, 'a5_hou22_geom': False}, 'q16_p78': {'a1_total_relighting': False, 'a2_ic_light': True, 'a3_hou21_shadowm': False, 'a4_difareli++': False, 'a5_hou22_geom': False}, 'q17_p70': {'a1_total_relighting': False, 'a2_hou22_geom': False, 'a3_ic_light': True, 'a4_difareli++': False, 'a5_hou21_shadowm': False}, 'q18_p70': {'a1_total_relighting': False, 'a2_hou22_geom': False, 'a3_ic_light': True, 'a4_difareli++': False, 'a5_hou21_shadowm': False}, 'q19_p77': {'a1_hou22_geom': False, 'a2_difareli++': False, 'a3_hou21_shadowm': False, 'a4_ic_light': True, 'a5_total_relighting': False}, 'q1_p50': {'a1_hou22_geom': False, 'a2_difareli++': False, 'a3_hou21_shadowm': True, 'a4_ic_light': False, 'a5_total_relighting': False}, 'q20_p77': {'a1_hou22_geom': False, 'a2_difareli++': False, 'a3_hou21_shadowm': False, 'a4_ic_light': True, 'a5_total_relighting': False}, 'q2_p50': {'a1_hou22_geom': False, 'a2_difareli++': False, 'a3_hou21_shadowm': True, 'a4_ic_light': False, 'a5_total_relighting': False}, 'q3_p48': {'a1_hou22_geom': False, 'a2_difareli++': False, 'a3_total_relighting': False, 'a4_ic_light': True, 'a5_hou21_shadowm': False}, 'q4_p48': {'a1_hou22_geom': False, 'a2_difareli++': False, 'a3_total_relighting': False, 'a4_ic_light': True, 'a5_hou21_shadowm': False}, 'q5_p26': {'a1_hou21_shadowm': False, 'a2_difareli++': False, 'a3_hou22_geom': False, 'a4_total_relighting': False, 'a5_ic_light': True}, 'q6_p26': {'a1_hou21_shadowm': False, 'a2_difareli++': False, 'a3_hou22_geom': False, 'a4_total_relighting': False, 'a5_ic_light': True}, 'q7_p16': {'a1_hou22_geom': False, 'a2_difareli++': False, 'a3_hou21_shadowm': False, 'a4_total_relighting': False, 'a5_ic_light': True}, 'q8_p16': {'a1_hou22_geom': False, 'a2_difareli++': False, 'a3_hou21_shadowm': False, 'a4_total_relighting': False, 'a5_ic_light': True}, 'q9_p38': {'a1_hou21_shadowm': False, 'a2_difareli++': False, 'a3_total_relighting': False, 'a4_ic_light': True, 'a5_hou22_geom': False}, 'q{qnum}_p16': {'a{anum}_{name}': False}, 'q{qnum}_p26': {'a{anum}_{name}': False}, 'q{qnum}_p38': {'a{anum}_{name}': False}, 'q{qnum}_p41': {'a{anum}_{name}': False}, 'q{qnum}_p47': {'a{anum}_{name}': False}, 'q{qnum}_p48': {'a{anum}_{name}': False}, 'q{qnum}_p50': {'a{anum}_{name}': False}, 'q{qnum}_p70': {'a{anum}_{name}': False}, 'q{qnum}_p77': {'a{anum}_{name}': False}, 'q{qnum}_p78': {'a{anum}_{name}': False}, 'q{qnum}_p{p}': {'a{anum}_{name}': False}}]
# ['a4_ic_light']
# ['a4_ic_light']
# ['a4_ic_light']
# ['a1_ic_light']
# ['a1_ic_light']
# ['a2_ic_light']
# ['a2_ic_light']
# ['a3_ic_light']
# ['a3_ic_light']
# ['a4_ic_light']
# ['a3_hou21_shadowm']
# ['a4_ic_light']
# ['a3_hou21_shadowm']
# ['a4_ic_light']
# ['a4_ic_light']
# ['a5_ic_light']
# ['a5_ic_light']
# ['a5_ic_light']
# ['a5_ic_light']
# ['a4_ic_light']
# 1
# [{'q10_p29': {'a1_ic_light': False, 'a2_hou21_shadowm': True, 'a3_difareli++': False, 'a4_hou22_geom': False, 'a5_total_relighting': False}, 'q11_p21': {'a1_total_relighting': False, 'a2_hou22_geom': False, 'a3_difareli++': True, 'a4_hou21_shadowm': False, 'a5_ic_light': False}, 'q12_p21': {'a1_total_relighting': False, 'a2_hou22_geom': False, 'a3_difareli++': True, 'a4_hou21_shadowm': False, 'a5_ic_light': False}, 'q13_p68': {'a1_total_relighting': False, 'a2_ic_light': True, 'a3_hou21_shadowm': False, 'a4_difareli++': False, 'a5_hou22_geom': False}, 'q14_p68': {'a1_total_relighting': False, 'a2_ic_light': True, 'a3_hou21_shadowm': False, 'a4_difareli++': False, 'a5_hou22_geom': False}, 'q15_p27': {'a1_hou22_geom': False, 'a2_difareli++': True, 'a3_total_relighting': False, 'a4_hou21_shadowm': False, 'a5_ic_light': False}, 'q16_p27': {'a1_hou22_geom': False, 'a2_difareli++': True, 'a3_total_relighting': False, 'a4_hou21_shadowm': False, 'a5_ic_light': False}, 'q17_p32': {'a1_hou22_geom': False, 'a2_difareli++': True, 'a3_total_relighting': False, 'a4_hou21_shadowm': False, 'a5_ic_light': False}, 'q18_p32': {'a1_hou22_geom': False, 'a2_difareli++': True, 'a3_total_relighting': False, 'a4_hou21_shadowm': False, 'a5_ic_light': False}, 'q19_p45': {'a1_difareli++': True, 'a2_total_relighting': False, 'a3_hou22_geom': False, 'a4_hou21_shadowm': False, 'a5_ic_light': False}, 'q1_p17': {'a1_hou22_geom': False, 'a2_difareli++': False, 'a3_total_relighting': True, 'a4_hou21_shadowm': False, 'a5_ic_light': False}, 'q20_p45': {'a1_difareli++': True, 'a2_total_relighting': False, 'a3_hou22_geom': False, 'a4_hou21_shadowm': False, 'a5_ic_light': False}, 'q2_p17': {'a1_hou22_geom': False, 'a2_difareli++': True, 'a3_total_relighting': False, 'a4_hou21_shadowm': False, 'a5_ic_light': False}, 'q3_p76': {'a1_hou21_shadowm': False, 'a2_difareli++': False, 'a3_ic_light': False, 'a4_total_relighting': True, 'a5_hou22_geom': False}, 'q4_p76': {'a1_hou21_shadowm': False, 'a2_difareli++': False, 'a3_ic_light': True, 'a4_total_relighting': False, 'a5_hou22_geom': False}, 'q5_p3': {'a1_total_relighting': False, 'a2_hou22_geom': False, 'a3_difareli++': True, 'a4_hou21_shadowm': False, 'a5_ic_light': False}, 'q6_p3': {'a1_total_relighting': False, 'a2_hou22_geom': False, 'a3_difareli++': True, 'a4_hou21_shadowm': False, 'a5_ic_light': False}, 'q7_p12': {'a1_hou22_geom': False, 'a2_difareli++': False, 'a3_ic_light': True, 'a4_hou21_shadowm': False, 'a5_total_relighting': False}, 'q8_p12': {'a1_hou22_geom': False, 'a2_difareli++': False, 'a3_ic_light': True, 'a4_hou21_shadowm': False, 'a5_total_relighting': False}, 'q9_p29': {'a1_ic_light': False, 'a2_hou21_shadowm': True, 'a3_difareli++': False, 'a4_hou22_geom': False, 'a5_total_relighting': False}, 'q{qnum}_p12': {'a{anum}_{name}': False}, 'q{qnum}_p17': {'a{anum}_{name}': False}, 'q{qnum}_p21': {'a{anum}_{name}': False}, 'q{qnum}_p27': {'a{anum}_{name}': False}, 'q{qnum}_p29': {'a{anum}_{name}': False}, 'q{qnum}_p3': {'a{anum}_{name}': False}, 'q{qnum}_p32': {'a{anum}_{name}': False}, 'q{qnum}_p45': {'a{anum}_{name}': False}, 'q{qnum}_p68': {'a{anum}_{name}': False}, 'q{qnum}_p76': {'a{anum}_{name}': False}, 'q{qnum}_p{p}': {'a{anum}_{name}': False}}]
# ['a2_hou21_shadowm']
# ['a3_difareli++']
# ['a3_difareli++']
# ['a2_ic_light']
# ['a2_ic_light']
# ['a2_difareli++']
# ['a2_difareli++']
# ['a2_difareli++']
# ['a2_difareli++']
# ['a1_difareli++']
# ['a3_total_relighting']
# ['a1_difareli++']
# ['a2_difareli++']
# ['a4_total_relighting']
# ['a3_ic_light']
# ['a3_difareli++']
# ['a3_difareli++']
# ['a3_ic_light']
# ['a3_ic_light']
# ['a2_hou21_shadowm']
# 1
# ...
# ['a5_ic_light']
# ['a5_ic_light']
# ['a3_difareli++']
# ['a3_ic_light']
# ['a5_difareli++']
# ['a4_total_relighting']
# ['a4_total_relighting']
# ['a3_hou21_shadowm']
# ['a2_hou22_geom']
# ['a2_hou21_shadowm']
# ['a2_ic_light']
# ['a2_hou21_shadowm']
# ['a2_ic_light']
# ['a1_total_relighting']
# ['a4_difareli++']
# ['a2_difareli++']
# ['a2_difareli++']
# ['a2_difareli++']
# ['a1_hou21_shadowm']
# ['a5_ic_light']
# 1
# [{'q10_p51': {'a1_hou21_shadowm': False, 'a2_difareli++': True, 'a3_total_relighting': False, 'a4_ic_light': False, 'a5_hou22_geom': False}, 'q11_p56': {'a1_total_relighting': False, 'a2_ic_light': False, 'a3_hou21_shadowm': False, 'a4_difareli++': False, 'a5_hou22_geom': True}, 'q12_p56': {'a1_total_relighting': False, 'a2_ic_light': False, 'a3_hou21_shadowm': False, 'a4_difareli++': False, 'a5_hou22_geom': True}, 'q13_p46': {'a1_difareli++': False, 'a2_ic_light': True, 'a3_hou22_geom': False, 'a4_hou21_shadowm': False, 'a5_total_relighting': False}, 'q14_p46': {'a1_difareli++': False, 'a2_ic_light': True, 'a3_hou22_geom': False, 'a4_hou21_shadowm': False, 'a5_total_relighting': False}, 'q15_p97': {'a1_hou22_geom': False, 'a2_difareli++': True, 'a3_hou21_shadowm': False, 'a4_ic_light': False, 'a5_total_relighting': False}, 'q16_p97': {'a1_hou22_geom': False, 'a2_difareli++': True, 'a3_hou21_shadowm': False, 'a4_ic_light': False, 'a5_total_relighting': False}, 'q17_p99': {'a1_hou21_shadowm': False, 'a2_difareli++': True, 'a3_total_relighting': False, 'a4_hou22_geom': False, 'a5_ic_light': False}, 'q18_p99': {'a1_hou21_shadowm': False, 'a2_difareli++': True, 'a3_total_relighting': False, 'a4_hou22_geom': False, 'a5_ic_light': False}, 'q19_p93': {'a1_hou22_geom': False, 'a2_difareli++': True, 'a3_hou21_shadowm': False, 'a4_ic_light': False, 'a5_total_relighting': False}, 'q1_p42': {'a1_hou22_geom': False, 'a2_difareli++': False, 'a3_total_relighting': False, 'a4_ic_light': True, 'a5_hou21_shadowm': False}, 'q20_p93': {'a1_hou22_geom': False, 'a2_difareli++': True, 'a3_hou21_shadowm': False, 'a4_ic_light': False, 'a5_total_relighting': False}, 'q2_p42': {'a1_hou22_geom': False, 'a2_difareli++': False, 'a3_total_relighting': False, 'a4_ic_light': True, 'a5_hou21_shadowm': False}, 'q3_p95': {'a1_hou22_geom': False, 'a2_ic_light': True, 'a3_difareli++': False, 'a4_hou21_shadowm': False, 'a5_total_relighting': False}, 'q4_p95': {'a1_hou22_geom': False, 'a2_ic_light': True, 'a3_difareli++': False, 'a4_hou21_shadowm': False, 'a5_total_relighting': False}, 'q5_p53': {'a1_total_relighting': False, 'a2_hou21_shadowm': False, 'a3_difareli++': False, 'a4_ic_light': True, 'a5_hou22_geom': False}, 'q6_p53': {'a1_total_relighting': False, 'a2_hou21_shadowm': False, 'a3_difareli++': False, 'a4_ic_light': True, 'a5_hou22_geom': False}, 'q7_p66': {'a1_ic_light': False, 'a2_hou22_geom': False, 'a3_total_relighting': False, 'a4_difareli++': True, 'a5_hou21_shadowm': False}, 'q8_p66': {'a1_ic_light': False, 'a2_hou22_geom': False, 'a3_total_relighting': False, 'a4_difareli++': True, 'a5_hou21_shadowm': False}, 'q9_p51': {'a1_hou21_shadowm': False, 'a2_difareli++': True, 'a3_total_relighting': False, 'a4_ic_light': False, 'a5_hou22_geom': False}, 'q{qnum}_p42': {'a{anum}_{name}': False}, 'q{qnum}_p46': {'a{anum}_{name}': False}, 'q{qnum}_p51': {'a{anum}_{name}': False}, 'q{qnum}_p53': {'a{anum}_{name}': False}, 'q{qnum}_p56': {'a{anum}_{name}': False}, 'q{qnum}_p66': {'a{anum}_{name}': False}, 'q{qnum}_p93': {'a{anum}_{name}': False}, 'q{qnum}_p95': {'a{anum}_{name}': False}, 'q{qnum}_p97': {'a{anum}_{name}': False}, 'q{qnum}_p99': {'a{anum}_{name}': False}, 'q{qnum}_p{p}': {'a{anum}_{name}': False}}]
# ['a2_difareli++']
# ['a5_hou22_geom']
# ['a5_hou22_geom']
# ['a2_ic_light']
# ['a2_ic_light']
# ['a2_difareli++']
# ['a2_difareli++']
# ['a2_difareli++']
# ['a2_difareli++']
# ['a2_difareli++']
# ['a4_ic_light']
# ['a2_difareli++']
# ['a4_ic_light']
# ['a2_ic_light']
# ['a2_ic_light']
# ['a4_ic_light']
# ['a4_ic_light']
# ['a4_difareli++']
# ['a4_difareli++']
# ['a2_difareli++']
# 1
# [{'q10_p51': {'a1_hou22_geom': False, 'a2_difareli++': False, 'a3_hou21_shadowm': False, 'a4_ic_light': True, 'a5_total_relighting': False}, 'q11_p56': {'a1_difareli++': False, 'a2_total_relighting': False, 'a3_hou22_geom': False, 'a4_ic_light': True, 'a5_hou21_shadowm': False}, 'q12_p56': {'a1_difareli++': False, 'a2_total_relighting': False, 'a3_hou22_geom': False, 'a4_ic_light': True, 'a5_hou21_shadowm': False}, 'q13_p46': {'a1_difareli++': True, 'a2_hou22_geom': False, 'a3_ic_light': False, 'a4_hou21_shadowm': False, 'a5_total_relighting': False}, 'q14_p46': {'a1_difareli++': True, 'a2_hou22_geom': False, 'a3_ic_light': False, 'a4_hou21_shadowm': False, 'a5_total_relighting': False}, 'q15_p97': {'a1_hou21_shadowm': False, 'a2_difareli++': True, 'a3_ic_light': False, 'a4_hou22_geom': False, 'a5_total_relighting': False}, 'q16_p97': {'a1_hou21_shadowm': False, 'a2_difareli++': True, 'a3_ic_light': False, 'a4_hou22_geom': False, 'a5_total_relighting': False}, 'q17_p99': {'a1_difareli++': True, 'a2_hou21_shadowm': False, 'a3_total_relighting': False, 'a4_ic_light': False, 'a5_hou22_geom': False}, 'q18_p99': {'a1_difareli++': True, 'a2_hou21_shadowm': False, 'a3_total_relighting': False, 'a4_ic_light': False, 'a5_hou22_geom': False}, 'q19_p93': {'a1_hou22_geom': False, 'a2_difareli++': True, 'a3_hou21_shadowm': False, 'a4_ic_light': False, 'a5_total_relighting': False}, 'q1_p42': {'a1_hou22_geom': False, 'a2_difareli++': False, 'a3_total_relighting': False, 'a4_hou21_shadowm': True, 'a5_ic_light': False}, 'q20_p93': {'a1_hou22_geom': False, 'a2_difareli++': True, 'a3_hou21_shadowm': False, 'a4_ic_light': False, 'a5_total_relighting': False}, 'q2_p42': {'a1_hou22_geom': False, 'a2_difareli++': False, 'a3_total_relighting': False, 'a4_hou21_shadowm': True, 'a5_ic_light': False}, 'q3_p95': {'a1_hou21_shadowm': False, 'a2_difareli++': False, 'a3_hou22_geom': False, 'a4_total_relighting': False, 'a5_ic_light': True}, 'q4_p95': {'a1_hou21_shadowm': False, 'a2_difareli++': False, 'a3_hou22_geom': False, 'a4_total_relighting': False, 'a5_ic_light': True}, 'q5_p53': {'a1_total_relighting': False, 'a2_ic_light': False, 'a3_hou21_shadowm': True, 'a4_difareli++': False, 'a5_hou22_geom': False}, 'q6_p53': {'a1_total_relighting': False, 'a2_ic_light': False, 'a3_hou21_shadowm': True, 'a4_difareli++': False, 'a5_hou22_geom': False}, 'q7_p66': {'a1_ic_light': False, 'a2_total_relighting': False, 'a3_hou21_shadowm': False, 'a4_difareli++': True, 'a5_hou22_geom': False}, 'q8_p66': {'a1_ic_light': False, 'a2_total_relighting': False, 'a3_hou21_shadowm': False, 'a4_difareli++': True, 'a5_hou22_geom': False}, 'q9_p51': {'a1_hou22_geom': False, 'a2_difareli++': False, 'a3_hou21_shadowm': False, 'a4_ic_light': True, 'a5_total_relighting': False}, 'q{qnum}_p42': {'a{anum}_{name}': False}, 'q{qnum}_p46': {'a{anum}_{name}': False}, 'q{qnum}_p51': {'a{anum}_{name}': False}, 'q{qnum}_p53': {'a{anum}_{name}': False}, 'q{qnum}_p56': {'a{anum}_{name}': False}, 'q{qnum}_p66': {'a{anum}_{name}': False}, 'q{qnum}_p93': {'a{anum}_{name}': False}, 'q{qnum}_p95': {'a{anum}_{name}': False}, 'q{qnum}_p97': {'a{anum}_{name}': False}, 'q{qnum}_p99': {'a{anum}_{name}': False}, 'q{qnum}_p{p}': {'a{anum}_{name}': False}}]
# ['a4_ic_light']
# ['a4_ic_light']
# ['a4_ic_light']
# ['a1_difareli++']
# ['a1_difareli++']
# ['a2_difareli++']
# ['a2_difareli++']
# ['a1_difareli++']
# ['a1_difareli++']
# ['a2_difareli++']
# ['a4_hou21_shadowm']
# ['a2_difareli++']
# ['a4_hou21_shadowm']
# ['a5_ic_light']
# ['a5_ic_light']
# ['a3_hou21_shadowm']
# ['a3_hou21_shadowm']
# ['a4_difareli++']
# ['a4_difareli++']
# ['a4_ic_light']
# 1
# [{'q10_p51': {'a1_hou22_geom': True, 'a2_difareli++': False, 'a3_hou21_shadowm': False, 'a4_ic_light': False, 'a5_total_relighting': False}, 'q11_p56': {'a1_hou22_geom': False, 'a2_difareli++': False, 'a3_hou21_shadowm': False, 'a4_total_relighting': True, 'a5_ic_light': False}, 'q12_p56': {'a1_hou22_geom': False, 'a2_difareli++': False, 'a3_hou21_shadowm': False, 'a4_total_relighting': True, 'a5_ic_light': False}, 'q13_p46': {'a1_difareli++': False, 'a2_hou22_geom': True, 'a3_total_relighting': False, 'a4_ic_light': False, 'a5_hou21_shadowm': False}, 'q14_p46': {'a1_difareli++': False, 'a2_hou22_geom': True, 'a3_total_relighting': False, 'a4_ic_light': False, 'a5_hou21_shadowm': False}, 'q15_p97': {'a1_hou22_geom': False, 'a2_difareli++': False, 'a3_total_relighting': False, 'a4_hou21_shadowm': True, 'a5_ic_light': False}, 'q16_p97': {'a1_hou22_geom': False, 'a2_difareli++': False, 'a3_total_relighting': False, 'a4_hou21_shadowm': True, 'a5_ic_light': False}, 'q17_p99': {'a1_ic_light': False, 'a2_hou22_geom': False, 'a3_total_relighting': False, 'a4_difareli++': True, 'a5_hou21_shadowm': False}, 'q18_p99': {'a1_ic_light': False, 'a2_hou22_geom': False, 'a3_total_relighting': False, 'a4_difareli++': True, 'a5_hou21_shadowm': False}, 'q19_p93': {'a1_total_relighting': False, 'a2_hou21_shadowm': False, 'a3_hou22_geom': False, 'a4_difareli++': True, 'a5_ic_light': False}, 'q1_p42': {'a1_hou22_geom': False, 'a2_difareli++': True, 'a3_total_relighting': False, 'a4_hou21_shadowm': False, 'a5_ic_light': False}, 'q20_p93': {'a1_total_relighting': False, 'a2_hou21_shadowm': False, 'a3_hou22_geom': False, 'a4_difareli++': True, 'a5_ic_light': False}, 'q2_p42': {'a1_hou22_geom': False, 'a2_difareli++': True, 'a3_total_relighting': False, 'a4_hou21_shadowm': False, 'a5_ic_light': False}, 'q3_p95': {'a1_ic_light': False, 'a2_difareli++': True, 'a3_hou22_geom': False, 'a4_total_relighting': False, 'a5_hou21_shadowm': False}, 'q4_p95': {'a1_ic_light': False, 'a2_difareli++': True, 'a3_hou22_geom': False, 'a4_total_relighting': False, 'a5_hou21_shadowm': False}, 'q5_p53': {'a1_hou22_geom': False, 'a2_difareli++': True, 'a3_total_relighting': False, 'a4_ic_light': False, 'a5_hou21_shadowm': False}, 'q6_p53': {'a1_hou22_geom': False, 'a2_difareli++': True, 'a3_total_relighting': False, 'a4_ic_light': False, 'a5_hou21_shadowm': False}, 'q7_p66': {'a1_hou21_shadowm': False, 'a2_total_relighting': False, 'a3_difareli++': True, 'a4_hou22_geom': False, 'a5_ic_light': False}, 'q8_p66': {'a1_hou21_shadowm': False, 'a2_total_relighting': False, 'a3_difareli++': True, 'a4_hou22_geom': False, 'a5_ic_light': False}, 'q9_p51': {'a1_hou22_geom': False, 'a2_difareli++': False, 'a3_hou21_shadowm': True, 'a4_ic_light': False, 'a5_total_relighting': False}, 'q{qnum}_p42': {'a{anum}_{name}': False}, 'q{qnum}_p46': {'a{anum}_{name}': False}, 'q{qnum}_p51': {'a{anum}_{name}': False}, 'q{qnum}_p53': {'a{anum}_{name}': False}, 'q{qnum}_p56': {'a{anum}_{name}': False}, 'q{qnum}_p66': {'a{anum}_{name}': False}, 'q{qnum}_p93': {'a{anum}_{name}': False}, 'q{qnum}_p95': {'a{anum}_{name}': False}, 'q{qnum}_p97': {'a{anum}_{name}': False}, 'q{qnum}_p99': {'a{anum}_{name}': False}, 'q{qnum}_p{p}': {'a{anum}_{name}': False}}]
# ['a1_hou22_geom']
# ['a4_total_relighting']
# ['a4_total_relighting']
# ['a2_hou22_geom']
# ['a2_hou22_geom']
# ['a4_hou21_shadowm']
# ['a4_hou21_shadowm']
# ['a4_difareli++']
# ['a4_difareli++']
# ['a4_difareli++']
# ['a2_difareli++']
# ['a4_difareli++']
# ['a2_difareli++']
# ['a2_difareli++']
# ['a2_difareli++']
# ['a2_difareli++']
# ['a2_difareli++']
# ['a3_difareli++']
# ['a3_difareli++']
# ['a3_hou21_shadowm']
# 1
# [{'q10_p73': {'a1_ic_light': False, 'a2_hou21_shadowm': False, 'a3_difareli++': False, 'a4_hou22_geom': False, 'a5_total_relighting': True}, 'q11_p9': {'a1_difareli++': False, 'a2_hou22_geom': False, 'a3_hou21_shadowm': True, 'a4_ic_light': False, 'a5_total_relighting': False}, 'q12_p9': {'a1_difareli++': False, 'a2_hou22_geom': False, 'a3_hou21_shadowm': True, 'a4_ic_light': False, 'a5_total_relighting': False}, 'q13_p72': {'a1_total_relighting': False, 'a2_difareli++': False, 'a3_hou22_geom': False, 'a4_hou21_shadowm': True, 'a5_ic_light': False}, 'q14_p72': {'a1_total_relighting': False, 'a2_difareli++': False, 'a3_hou22_geom': False, 'a4_hou21_shadowm': True, 'a5_ic_light': False}, 'q15_p7': {'a1_hou22_geom': False, 'a2_difareli++': False, 'a3_ic_light': False, 'a4_hou21_shadowm': True, 'a5_total_relighting': False}, 'q16_p7': {'a1_hou22_geom': False, 'a2_difareli++': False, 'a3_ic_light': False, 'a4_hou21_shadowm': True, 'a5_total_relighting': False}, 'q17_p8': {'a1_hou22_geom': False, 'a2_hou21_shadowm': False, 'a3_ic_light': False, 'a4_total_relighting': False, 'a5_difareli++': True}, 'q18_p8': {'a1_hou22_geom': False, 'a2_hou21_shadowm': False, 'a3_ic_light': False, 'a4_total_relighting': False, 'a5_difareli++': True}, 'q1_p60': {'a1_hou22_geom': False, 'a2_hou21_shadowm': False, 'a3_difareli++': False, 'a4_ic_light': True, 'a5_total_relighting': False}, 'q2_p60': {'a1_hou22_geom': False, 'a2_hou21_shadowm': False, 'a3_difareli++': False, 'a4_ic_light': True, 'a5_total_relighting': False}, 'q3_p24': {'a1_difareli++': False, 'a2_hou22_geom': False, 'a3_total_relighting': True, 'a4_hou21_shadowm': False, 'a5_ic_light': False}, 'q4_p24': {'a1_difareli++': False, 'a2_hou22_geom': False, 'a3_total_relighting': True, 'a4_hou21_shadowm': False, 'a5_ic_light': False}, 'q5_p81': {'a1_hou21_shadowm': False, 'a2_ic_light': False, 'a3_difareli++': False, 'a4_total_relighting': True, 'a5_hou22_geom': False}, 'q6_p81': {'a1_hou21_shadowm': False, 'a2_ic_light': False, 'a3_difareli++': False, 'a4_total_relighting': True, 'a5_hou22_geom': False}, 'q7_p52': {'a1_difareli++': False, 'a2_ic_light': False, 'a3_hou22_geom': False, 'a4_total_relighting': True, 'a5_hou21_shadowm': False}, 'q8_p52': {'a1_difareli++': False, 'a2_ic_light': False, 'a3_hou22_geom': False, 'a4_total_relighting': True, 'a5_hou21_shadowm': False}, 'q9_p73': {'a1_ic_light': False, 'a2_hou21_shadowm': False, 'a3_difareli++': False, 'a4_hou22_geom': True, 'a5_total_relighting': False}, 'q{qnum}_p24': {'a{anum}_{name}': False}, 'q{qnum}_p52': {'a{anum}_{name}': False}, 'q{qnum}_p60': {'a{anum}_{name}': False}, 'q{qnum}_p7': {'a{anum}_{name}': False}, 'q{qnum}_p72': {'a{anum}_{name}': False}, 'q{qnum}_p73': {'a{anum}_{name}': False}, 'q{qnum}_p8': {'a{anum}_{name}': False}, 'q{qnum}_p81': {'a{anum}_{name}': False}, 'q{qnum}_p9': {'a{anum}_{name}': False}, 'q{qnum}_p{p}': {'a{anum}_{name}': False}}]
# ['a5_total_relighting']
# ['a3_hou21_shadowm']
# ['a3_hou21_shadowm']
# ['a4_hou21_shadowm']
# ['a4_hou21_shadowm']
# ['a4_hou21_shadowm']
# ['a4_hou21_shadowm']
# ['a5_difareli++']
# ['a5_difareli++']
# ['a4_ic_light']
# ['a4_ic_light']
# ['a3_total_relighting']
# ['a3_total_relighting']
# ['a4_total_relighting']
# ['a4_total_relighting']
# ['a4_total_relighting']
# ['a4_total_relighting']
# ['a4_hou22_geom']
# []
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# /tmp/ipykernel_1721391/3981347212.py in <module>
#      33         tmp = [x for x, y in answer[a].items() if y is True]
#      34         print(tmp)
# ---> 35         assert len(tmp) == 1
#      36         qidx = int(a.split('_')[0][1:])
#      37         user_ans = tmp[0][3:]
#
# AssertionError:
